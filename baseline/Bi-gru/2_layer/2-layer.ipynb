# %%
# load the datapath that has been cleaned and preprocessed 

import pandas as pd 

# Dataset paths
DATA_PATHS = {
    "train": "/home/gibannn/kuliah/sem3/paper/SMILES2VEC/code/SMILES/train_set_balanced.xlsx",
    "test":  "/home/gibannn/kuliah/sem3/paper/SMILES2VEC/code/SMILES/test_set_balanced.xlsx",
    "val":   "/home/gibannn/kuliah/sem3/paper/SMILES2VEC/code/SMILES/val_set_balanced.xlsx"
}

print("Datapaths loaded\n")


def load_dataset(path, name):
    """Load dataset and split into features (X) and labels (y)."""
    
    df = pd.read_excel(path)
    
    X = df.drop(columns="labels")
    y = df["labels"]

    print(f"{name.upper()} DATA")
    print(f"X_{name} shape: {X.shape} | y_{name} shape: {y.shape}")
    
    label_dist = y.value_counts().rename(index={0: "Label 0", 1: "Label 1"})
    print("Label distribution:\n", label_dist, "\n")

    return X, y


# Load datasets
X_train, y_train = load_dataset(DATA_PATHS["train"], "train")
X_test, y_test   = load_dataset(DATA_PATHS["test"], "test")
X_val, y_val     = load_dataset(DATA_PATHS["val"], "val")
# Out:
# Datapaths loaded
#
# TRAIN DATA
# X_train shape: (8260, 271) | y_train shape: (8260,)
# Label distribution:
#  labels
# Label 0    4167
# Label 1    4093
# Name: count, dtype: int64
#
# TEST DATA
# X_test shape: (1833, 271) | y_test shape: (1833,)
# Label distribution:
#  labels
# Label 1    940
# Label 0    893
# Name: count, dtype: int64
#
# VAL DATA
# X_val shape: (1806, 271) | y_val shape: (1806,)
# Label distribution:
#  labels
# Label 1    913
# Label 0    893
# Name: count, dtype: int64

# %%
vocab_size = int(
    max(
        X_train.to_numpy().max(),
        X_test.to_numpy().max(),
        X_val.to_numpy().max()
    )
)

# Maximum sequence length
MAX_LEN = X_train.shape[1]

print("Dataset Statistics")
print("------------------")
print(f"Vocabulary size: {vocab_size}")
print(f"Max sequence length: {MAX_LEN}")

print("\nClass distribution in training set (after ADASYN balancing):")
print(
    y_train.value_counts()
    .rename(index={
        0: "Label 0 (Negative)",
        1: "Label 1 (Positive)"
    })
)
# Out:
# Dataset Statistics
# ------------------
# Vocabulary size: 132
# Max sequence length: 271
#
# Class distribution in training set (after ADASYN balancing):
# labels
# Label 0 (Negative)    4167
# Label 1 (Positive)    4093
# Name: count, dtype: int64

# %%
# ================================
# Environment Configuration
# ================================
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"       # Suppress TensorFlow logs
os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"     # Use GPU 0 (RTX 4060)   
os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"      # Disable OneDNN optimizations


# ================================
# Imports
# ================================
import warnings
import random
import time

import numpy as np
import tensorflow as tf
import sklearn.metrics as metrics

warnings.filterwarnings("ignore", category=FutureWarning)


# ================================
# Reproducibility
# ================================
RANDOM_STATE = 116

def set_seeds(seed: int = 116):
    """Set seeds for reproducibility."""
    np.random.seed(seed)
    random.seed(seed)
    tf.random.set_seed(seed)


set_seeds(RANDOM_STATE)


# ================================
# GPU Configuration
# ================================
def setup_gpu():
    """Configure TensorFlow GPU memory growth."""
    
    gpus = tf.config.list_physical_devices("GPU")

    if not gpus:
        print("No GPU detected. Using CPU.")
        return

    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)

        logical_gpus = tf.config.list_logical_devices("GPU")

        print(f"GPUs available: {len(gpus)} physical | {len(logical_gpus)} logical")

    except RuntimeError as e:
        print("GPU setup failed:", e)


setup_gpu()


# ================================
# Training Configuration
# ================================
def set_training_config(batch_size=256, iterations=128, epochs=100):
    """Define training hyperparameters."""
    
    config = {
        "BATCH_SIZE": batch_size,
        "ITERATIONS": iterations,
        "EPOCHS": epochs
    }

    return config


TRAIN_CONFIG = set_training_config()

BATCH_SIZE = TRAIN_CONFIG["BATCH_SIZE"]
ITERATIONS = TRAIN_CONFIG["ITERATIONS"]
EPOCHS = TRAIN_CONFIG["EPOCHS"]

print(f"Training config -> Batch: {BATCH_SIZE} | Iterations: {ITERATIONS} | Epochs: {EPOCHS}")
# Out:
# /home/gibannn/miniconda3/envs/RISET-SMILES/lib/python3.11/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# GPUs available: 1 physical | 1 logical
# Training config -> Batch: 256 | Iterations: 128 | Epochs: 100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773713084.541880   69591 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5560 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:65:00.0, compute capability: 8.9

# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Embedding, Conv1D, BatchNormalization,
    MaxPooling1D, GRU, Bidirectional,
    Dense, Dropout
)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import plot_model



# Paths (simple and portable)

MODEL_DIR = "./model"
IMAGE_DIR = "./image"

os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(IMAGE_DIR, exist_ok=True)

MODEL_FILE = os.path.join(MODEL_DIR, "best_bigru_conv_model.h5")
MODEL_IMAGE = os.path.join(IMAGE_DIR, "bigru_conv_architecture.png")



# Model Architecture

def build_bigru_conv_model(sequence_length, vocabulary_size):

    set_seeds(RANDOM_STATE)

    model = Sequential([

        # Embedding
        Embedding(
            input_dim=vocabulary_size + 1,
            output_dim=128,
            mask_zero=False
        ),
        
        #add second layer of Bidirectional GRU
        Bidirectional(
            GRU(
                64,
                return_sequences=False,
                dropout=0.3
            )
        ),

        # Bidirectional GRU
        Bidirectional(
            GRU(
                32,
                return_sequences=False,
                dropout=0.3
            )
        ),


        # Output layer
        Dense(1, activation="sigmoid")
    ])

    return model



# Build Model

model = build_bigru_conv_model(MAX_LEN, vocab_size)

loss = tf.keras.losses.BinaryFocalCrossentropy(gamma=2)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss=loss,
    metrics=[
        "accuracy",
        tf.keras.metrics.AUC(name="auc")
    ]
)

model.build(input_shape=(None, MAX_LEN))

print("Model built successfully")
model.summary()



# Callbacks

early_stopping = EarlyStopping(
    monitor="val_auc",
    mode="max",
    patience=3,
    restore_best_weights=True,
    verbose=1
)

model_checkpoint = ModelCheckpoint(
    filepath=MODEL_FILE,
    monitor="val_auc",
    mode="max",
    save_best_only=True,
    verbose=1
)


# Save Model Architecture Diagram
plot_model(
    model,
    to_file=MODEL_IMAGE,
    show_shapes=True,
    show_layer_names=True
)

print(f"Model diagram saved to: {MODEL_IMAGE}")
# Out:
# /home/gibannn/miniconda3/envs/RISET-SMILES/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model built successfully
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 271, 128)       │        17,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 271, 128)       │        74,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 64)             │        31,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 122,689 (479.25 KB)
#  Trainable params: 122,689 (479.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Model diagram saved to: ./image/bigru_conv_architecture.png

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score

def compute_classification_metrics(y_true, y_pred):
    """
    Returns TP, TN, FP, FN, Precision, Recall, F1, Accuracy
    """
    cm = confusion_matrix(y_true, y_pred)
    
    tn, fp, fn, tp = cm.ravel()

    precision = precision_score(y_true, y_pred, zero_division=0)
    recall    = recall_score(y_true, y_pred, zero_division=0)
    f1        = f1_score(y_true, y_pred, zero_division=0)
    accuracy  = accuracy_score(y_true, y_pred)

    return {
        "TP": tp,
        "TN": tn,
        "FP": fp,
        "FN": fn,
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1,
        "Accuracy": accuracy
    }

print("the function to compute classification metrics have been defined")
# Out:
# the function to compute classification metrics have been defined

# %%
import os
import time
import pandas as pd
import numpy as np
import tensorflow as tf
from datetime import timedelta
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


def to_numpy(x):
    """Convert pandas objects to numpy arrays."""
    return x.values if hasattr(x, "values") else x


def train_and_evaluate_model(
    X_train, y_train,
    X_val, y_val,
    X_test, y_test,
    epochs=100,
    batch_size=128,
    learning_rate=3e-4,
    model_name="BiGRU+CNN",
    model_save_path="./model/best_model.keras",
    patience=5,
    verbose=1
):
    """
    Train and evaluate sequence classification model.
    """

    print(f"TRAINING {model_name}")
    print("=" * 50)

    start_time = time.time()

    # Convert datasets
    X_train, y_train = to_numpy(X_train), to_numpy(y_train)
    X_val, y_val = to_numpy(X_val), to_numpy(y_val)
    X_test, y_test = to_numpy(X_test), to_numpy(y_test)

    
    # Build model
    
    print("\nBuilding model...")
    model = build_bigru_conv_model(MAX_LEN, vocab_size)

    
    # Compile
    
    print("[2/4] Compiling model...")

    loss_fn = tf.keras.losses.BinaryFocalCrossentropy(gamma=2)

    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss=loss_fn,
        metrics=[
            "accuracy",
            tf.keras.metrics.AUC(name="auc")
        ]
    )

    model.build(input_shape=(None, MAX_LEN))

    if verbose:
        model.summary()

    
    # Callbacks
    
    os.makedirs(os.path.dirname(model_save_path), exist_ok=True)

    callbacks = [

        EarlyStopping(
            monitor="val_auc",
            mode="max",
            patience=patience,
            restore_best_weights=True,
            verbose=1
        ),

        ModelCheckpoint(
            filepath=model_save_path,
            monitor="val_auc",
            mode="max",
            save_best_only=True,
            verbose=1
        )
    ]

    
    # Training
    
    print("\nTraining model...")
    print(f"Epochs: {epochs}")
    print(f"Batch size: {batch_size}")
    print(f"Training samples: {len(X_train)}")

    history = model.fit(
        X_train,
        y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=callbacks,
        verbose=verbose
    )

    training_time = time.time() - start_time

    
    # Evaluation
    
    print("\nEvaluating model...")

    y_pred_prob = model.predict(X_test, verbose=0)
    y_pred = (y_pred_prob > 0.5).astype(int)

    metrics_dict = compute_classification_metrics(y_test, y_pred)

    results_df = pd.DataFrame([{
        "Model": model_name,
        "Accuracy": metrics_dict["Accuracy"],
        "Precision": metrics_dict["Precision"],
        "Recall": metrics_dict["Recall"],
        "F1": metrics_dict["F1-Score"],
        "TP": metrics_dict["TP"],
        "TN": metrics_dict["TN"],
        "FP": metrics_dict["FP"],
        "FN": metrics_dict["FN"],
        "Training_Time": str(timedelta(seconds=int(training_time))),
        "Epochs": len(history.history["loss"])
    }])

    print("\nTRAINING COMPLETE")
    print("=" * 50)
    print(results_df.to_string(index=False))

    return model, history, results_df

# %%
model, history, results = train_and_evaluate_model(
    X_train,
    y_train,
    X_val,
    y_val,
    X_test,
    y_test,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    model_name="BiGRU",
    model_save_path="./model/best_bigru_model.keras"
)
# Out:
# TRAINING BiGRU
# ==================================================
#
# Building model...
# [2/4] Compiling model...
# /home/gibannn/miniconda3/envs/RISET-SMILES/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 271, 128)       │        17,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 271, 128)       │        74,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ (None, 64)             │        31,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 122,689 (479.25 KB)
#  Trainable params: 122,689 (479.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Training model...
# Epochs: 100
# Batch size: 256
# Training samples: 8260
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.6843 - auc: 0.7598 - loss: 0.1587
# Epoch 1: val_auc improved from None to 0.89232, saving model to ./model/best_bigru_model.keras
#
# Epoch 1: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 18s 264ms/step - accuracy: 0.7391 - auc: 0.8155 - loss: 0.1455 - val_accuracy: 0.7924 - val_auc: 0.8923 - val_loss: 0.1102
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8101 - auc: 0.8905 - loss: 0.1057
# Epoch 2: val_auc improved from 0.89232 to 0.94076, saving model to ./model/best_bigru_model.keras
#
# Epoch 2: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.8277 - auc: 0.9024 - loss: 0.0992 - val_accuracy: 0.8732 - val_auc: 0.9408 - val_loss: 0.0753
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8815 - auc: 0.9384 - loss: 0.0763
# Epoch 3: val_auc improved from 0.94076 to 0.95592, saving model to ./model/best_bigru_model.keras
#
# Epoch 3: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 217ms/step - accuracy: 0.8841 - auc: 0.9408 - loss: 0.0744 - val_accuracy: 0.9053 - val_auc: 0.9559 - val_loss: 0.0614
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9014 - auc: 0.9480 - loss: 0.0675
# Epoch 4: val_auc improved from 0.95592 to 0.95760, saving model to ./model/best_bigru_model.keras
#
# Epoch 4: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 225ms/step - accuracy: 0.9013 - auc: 0.9479 - loss: 0.0670 - val_accuracy: 0.9125 - val_auc: 0.9576 - val_loss: 0.0584
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9064 - auc: 0.9511 - loss: 0.0637
# Epoch 5: val_auc improved from 0.95760 to 0.95888, saving model to ./model/best_bigru_model.keras
#
# Epoch 5: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 233ms/step - accuracy: 0.9064 - auc: 0.9514 - loss: 0.0636 - val_accuracy: 0.9164 - val_auc: 0.9589 - val_loss: 0.0569
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9095 - auc: 0.9521 - loss: 0.0627
# Epoch 6: val_auc did not improve from 0.95888
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 226ms/step - accuracy: 0.9073 - auc: 0.9516 - loss: 0.0635 - val_accuracy: 0.9153 - val_auc: 0.9582 - val_loss: 0.0574
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9096 - auc: 0.9522 - loss: 0.0618
# Epoch 7: val_auc did not improve from 0.95888
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 231ms/step - accuracy: 0.9090 - auc: 0.9512 - loss: 0.0625 - val_accuracy: 0.9169 - val_auc: 0.9580 - val_loss: 0.0585
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9119 - auc: 0.9514 - loss: 0.0610
# Epoch 8: val_auc did not improve from 0.95888
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 222ms/step - accuracy: 0.9127 - auc: 0.9512 - loss: 0.0613 - val_accuracy: 0.9208 - val_auc: 0.9584 - val_loss: 0.0575
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9130 - auc: 0.9513 - loss: 0.0619
# Epoch 9: val_auc did not improve from 0.95888
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - accuracy: 0.9138 - auc: 0.9518 - loss: 0.0615 - val_accuracy: 0.9169 - val_auc: 0.9584 - val_loss: 0.0576
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9135 - auc: 0.9529 - loss: 0.0599
# Epoch 10: val_auc improved from 0.95888 to 0.95930, saving model to ./model/best_bigru_model.keras
#
# Epoch 10: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 226ms/step - accuracy: 0.9149 - auc: 0.9522 - loss: 0.0605 - val_accuracy: 0.9186 - val_auc: 0.9593 - val_loss: 0.0572
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9142 - auc: 0.9507 - loss: 0.0616
# Epoch 11: val_auc did not improve from 0.95930
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - accuracy: 0.9155 - auc: 0.9511 - loss: 0.0611 - val_accuracy: 0.9192 - val_auc: 0.9593 - val_loss: 0.0571
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9151 - auc: 0.9535 - loss: 0.0594
# Epoch 12: val_auc improved from 0.95930 to 0.96030, saving model to ./model/best_bigru_model.keras
#
# Epoch 12: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 228ms/step - accuracy: 0.9157 - auc: 0.9534 - loss: 0.0597 - val_accuracy: 0.9208 - val_auc: 0.9603 - val_loss: 0.0566
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9160 - auc: 0.9547 - loss: 0.0591
# Epoch 13: val_auc improved from 0.96030 to 0.96069, saving model to ./model/best_bigru_model.keras
#
# Epoch 13: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 216ms/step - accuracy: 0.9163 - auc: 0.9538 - loss: 0.0595 - val_accuracy: 0.9214 - val_auc: 0.9607 - val_loss: 0.0560
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9180 - auc: 0.9542 - loss: 0.0589
# Epoch 14: val_auc improved from 0.96069 to 0.96109, saving model to ./model/best_bigru_model.keras
#
# Epoch 14: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - accuracy: 0.9165 - auc: 0.9537 - loss: 0.0591 - val_accuracy: 0.9197 - val_auc: 0.9611 - val_loss: 0.0559
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9165 - auc: 0.9546 - loss: 0.0588
# Epoch 15: val_auc improved from 0.96109 to 0.96133, saving model to ./model/best_bigru_model.keras
#
# Epoch 15: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 228ms/step - accuracy: 0.9169 - auc: 0.9543 - loss: 0.0593 - val_accuracy: 0.9214 - val_auc: 0.9613 - val_loss: 0.0555
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9194 - auc: 0.9545 - loss: 0.0584
# Epoch 16: val_auc improved from 0.96133 to 0.96143, saving model to ./model/best_bigru_model.keras
#
# Epoch 16: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 231ms/step - accuracy: 0.9180 - auc: 0.9544 - loss: 0.0587 - val_accuracy: 0.9219 - val_auc: 0.9614 - val_loss: 0.0553
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9173 - auc: 0.9556 - loss: 0.0585
# Epoch 17: val_auc improved from 0.96143 to 0.96182, saving model to ./model/best_bigru_model.keras
#
# Epoch 17: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 219ms/step - accuracy: 0.9183 - auc: 0.9559 - loss: 0.0581 - val_accuracy: 0.9230 - val_auc: 0.9618 - val_loss: 0.0551
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9118 - auc: 0.9514 - loss: 0.0621
# Epoch 18: val_auc did not improve from 0.96182
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - accuracy: 0.9077 - auc: 0.9481 - loss: 0.0640 - val_accuracy: 0.9181 - val_auc: 0.9581 - val_loss: 0.0577
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9113 - auc: 0.9527 - loss: 0.0609
# Epoch 19: val_auc did not improve from 0.96182
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 206ms/step - accuracy: 0.9109 - auc: 0.9535 - loss: 0.0603 - val_accuracy: 0.9214 - val_auc: 0.9606 - val_loss: 0.0554
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9137 - auc: 0.9565 - loss: 0.0578
# Epoch 20: val_auc improved from 0.96182 to 0.96204, saving model to ./model/best_bigru_model.keras
#
# Epoch 20: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 243ms/step - accuracy: 0.9154 - auc: 0.9565 - loss: 0.0578 - val_accuracy: 0.9219 - val_auc: 0.9620 - val_loss: 0.0546
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9146 - auc: 0.9571 - loss: 0.0573
# Epoch 21: val_auc improved from 0.96204 to 0.96333, saving model to ./model/best_bigru_model.keras
#
# Epoch 21: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 251ms/step - accuracy: 0.9167 - auc: 0.9567 - loss: 0.0573 - val_accuracy: 0.9247 - val_auc: 0.9633 - val_loss: 0.0539
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9171 - auc: 0.9592 - loss: 0.0560
# Epoch 22: val_auc improved from 0.96333 to 0.96440, saving model to ./model/best_bigru_model.keras
#
# Epoch 22: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 263ms/step - accuracy: 0.9185 - auc: 0.9585 - loss: 0.0561 - val_accuracy: 0.9247 - val_auc: 0.9644 - val_loss: 0.0531
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9184 - auc: 0.9596 - loss: 0.0555
# Epoch 23: val_auc improved from 0.96440 to 0.96526, saving model to ./model/best_bigru_model.keras
#
# Epoch 23: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 272ms/step - accuracy: 0.9190 - auc: 0.9598 - loss: 0.0554 - val_accuracy: 0.9241 - val_auc: 0.9653 - val_loss: 0.0526
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.9158 - auc: 0.9602 - loss: 0.0553
# Epoch 24: val_auc improved from 0.96526 to 0.96551, saving model to ./model/best_bigru_model.keras
#
# Epoch 24: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 263ms/step - accuracy: 0.9177 - auc: 0.9597 - loss: 0.0553 - val_accuracy: 0.9252 - val_auc: 0.9655 - val_loss: 0.0534
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9189 - auc: 0.9615 - loss: 0.0546
# Epoch 25: val_auc improved from 0.96551 to 0.96642, saving model to ./model/best_bigru_model.keras
#
# Epoch 25: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 281ms/step - accuracy: 0.9201 - auc: 0.9601 - loss: 0.0552 - val_accuracy: 0.9264 - val_auc: 0.9664 - val_loss: 0.0531
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9218 - auc: 0.9618 - loss: 0.0543
# Epoch 26: val_auc improved from 0.96642 to 0.96679, saving model to ./model/best_bigru_model.keras
#
# Epoch 26: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 269ms/step - accuracy: 0.9215 - auc: 0.9605 - loss: 0.0548 - val_accuracy: 0.9280 - val_auc: 0.9668 - val_loss: 0.0529
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9200 - auc: 0.9616 - loss: 0.0541
# Epoch 27: val_auc improved from 0.96679 to 0.96706, saving model to ./model/best_bigru_model.keras
#
# Epoch 27: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 284ms/step - accuracy: 0.9213 - auc: 0.9615 - loss: 0.0541 - val_accuracy: 0.9275 - val_auc: 0.9671 - val_loss: 0.0523
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9197 - auc: 0.9630 - loss: 0.0539
# Epoch 28: val_auc improved from 0.96706 to 0.96745, saving model to ./model/best_bigru_model.keras
#
# Epoch 28: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 289ms/step - accuracy: 0.9208 - auc: 0.9626 - loss: 0.0541 - val_accuracy: 0.9286 - val_auc: 0.9675 - val_loss: 0.0521
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9190 - auc: 0.9645 - loss: 0.0531
# Epoch 29: val_auc improved from 0.96745 to 0.96762, saving model to ./model/best_bigru_model.keras
#
# Epoch 29: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 279ms/step - accuracy: 0.9195 - auc: 0.9635 - loss: 0.0535 - val_accuracy: 0.9280 - val_auc: 0.9676 - val_loss: 0.0519
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9199 - auc: 0.9641 - loss: 0.0530
# Epoch 30: val_auc improved from 0.96762 to 0.96778, saving model to ./model/best_bigru_model.keras
#
# Epoch 30: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 270ms/step - accuracy: 0.9208 - auc: 0.9637 - loss: 0.0532 - val_accuracy: 0.9291 - val_auc: 0.9678 - val_loss: 0.0521
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9178 - auc: 0.9630 - loss: 0.0539
# Epoch 31: val_auc improved from 0.96778 to 0.96814, saving model to ./model/best_bigru_model.keras
#
# Epoch 31: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 272ms/step - accuracy: 0.9209 - auc: 0.9631 - loss: 0.0537 - val_accuracy: 0.9286 - val_auc: 0.9681 - val_loss: 0.0517
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9195 - auc: 0.9643 - loss: 0.0532
# Epoch 32: val_auc improved from 0.96814 to 0.96852, saving model to ./model/best_bigru_model.keras
#
# Epoch 32: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 285ms/step - accuracy: 0.9212 - auc: 0.9643 - loss: 0.0530 - val_accuracy: 0.9291 - val_auc: 0.9685 - val_loss: 0.0513
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9189 - auc: 0.9650 - loss: 0.0526
# Epoch 33: val_auc improved from 0.96852 to 0.96876, saving model to ./model/best_bigru_model.keras
#
# Epoch 33: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 267ms/step - accuracy: 0.9214 - auc: 0.9647 - loss: 0.0525 - val_accuracy: 0.9302 - val_auc: 0.9688 - val_loss: 0.0511
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9216 - auc: 0.9662 - loss: 0.0521
# Epoch 34: val_auc improved from 0.96876 to 0.96878, saving model to ./model/best_bigru_model.keras
#
# Epoch 34: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 284ms/step - accuracy: 0.9220 - auc: 0.9652 - loss: 0.0524 - val_accuracy: 0.9313 - val_auc: 0.9688 - val_loss: 0.0511
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9198 - auc: 0.9665 - loss: 0.0522
# Epoch 35: val_auc improved from 0.96878 to 0.96888, saving model to ./model/best_bigru_model.keras
#
# Epoch 35: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 267ms/step - accuracy: 0.9208 - auc: 0.9659 - loss: 0.0523 - val_accuracy: 0.9286 - val_auc: 0.9689 - val_loss: 0.0512
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.9201 - auc: 0.9674 - loss: 0.0514
# Epoch 36: val_auc improved from 0.96888 to 0.96897, saving model to ./model/best_bigru_model.keras
#
# Epoch 36: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 263ms/step - accuracy: 0.9207 - auc: 0.9663 - loss: 0.0520 - val_accuracy: 0.9319 - val_auc: 0.9690 - val_loss: 0.0507
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9220 - auc: 0.9663 - loss: 0.0520
# Epoch 37: val_auc improved from 0.96897 to 0.96903, saving model to ./model/best_bigru_model.keras
#
# Epoch 37: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 260ms/step - accuracy: 0.9236 - auc: 0.9668 - loss: 0.0515 - val_accuracy: 0.9297 - val_auc: 0.9690 - val_loss: 0.0509
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9208 - auc: 0.9673 - loss: 0.0512
# Epoch 38: val_auc did not improve from 0.96903
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 252ms/step - accuracy: 0.9217 - auc: 0.9666 - loss: 0.0514 - val_accuracy: 0.9297 - val_auc: 0.9688 - val_loss: 0.0506
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9206 - auc: 0.9663 - loss: 0.0523
# Epoch 39: val_auc improved from 0.96903 to 0.96917, saving model to ./model/best_bigru_model.keras
#
# Epoch 39: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 264ms/step - accuracy: 0.9209 - auc: 0.9657 - loss: 0.0527 - val_accuracy: 0.9302 - val_auc: 0.9692 - val_loss: 0.0506
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9200 - auc: 0.9684 - loss: 0.0513
# Epoch 40: val_auc improved from 0.96917 to 0.96935, saving model to ./model/best_bigru_model.keras
#
# Epoch 40: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 268ms/step - accuracy: 0.9226 - auc: 0.9674 - loss: 0.0515 - val_accuracy: 0.9302 - val_auc: 0.9694 - val_loss: 0.0502
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.9209 - auc: 0.9675 - loss: 0.0512
# Epoch 41: val_auc improved from 0.96935 to 0.96960, saving model to ./model/best_bigru_model.keras
#
# Epoch 41: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 263ms/step - accuracy: 0.9228 - auc: 0.9668 - loss: 0.0516 - val_accuracy: 0.9324 - val_auc: 0.9696 - val_loss: 0.0500
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.9231 - auc: 0.9674 - loss: 0.0512
# Epoch 42: val_auc did not improve from 0.96960
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 258ms/step - accuracy: 0.9235 - auc: 0.9676 - loss: 0.0512 - val_accuracy: 0.9308 - val_auc: 0.9696 - val_loss: 0.0498
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9207 - auc: 0.9685 - loss: 0.0509
# Epoch 43: val_auc improved from 0.96960 to 0.97007, saving model to ./model/best_bigru_model.keras
#
# Epoch 43: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 268ms/step - accuracy: 0.9222 - auc: 0.9681 - loss: 0.0509 - val_accuracy: 0.9291 - val_auc: 0.9701 - val_loss: 0.0504
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.9212 - auc: 0.9674 - loss: 0.0514
# Epoch 44: val_auc did not improve from 0.97007
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 254ms/step - accuracy: 0.9236 - auc: 0.9678 - loss: 0.0511 - val_accuracy: 0.9313 - val_auc: 0.9700 - val_loss: 0.0499
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9232 - auc: 0.9687 - loss: 0.0504
# Epoch 45: val_auc improved from 0.97007 to 0.97022, saving model to ./model/best_bigru_model.keras
#
# Epoch 45: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 273ms/step - accuracy: 0.9235 - auc: 0.9682 - loss: 0.0506 - val_accuracy: 0.9302 - val_auc: 0.9702 - val_loss: 0.0495
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9213 - auc: 0.9690 - loss: 0.0504
# Epoch 46: val_auc improved from 0.97022 to 0.97044, saving model to ./model/best_bigru_model.keras
#
# Epoch 46: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 274ms/step - accuracy: 0.9226 - auc: 0.9688 - loss: 0.0505 - val_accuracy: 0.9302 - val_auc: 0.9704 - val_loss: 0.0495
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9218 - auc: 0.9698 - loss: 0.0499
# Epoch 47: val_auc did not improve from 0.97044
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 265ms/step - accuracy: 0.9230 - auc: 0.9693 - loss: 0.0501 - val_accuracy: 0.9286 - val_auc: 0.9704 - val_loss: 0.0494
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.9187 - auc: 0.9696 - loss: 0.0499
# Epoch 48: val_auc improved from 0.97044 to 0.97066, saving model to ./model/best_bigru_model.keras
#
# Epoch 48: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 272ms/step - accuracy: 0.9222 - auc: 0.9692 - loss: 0.0498 - val_accuracy: 0.9280 - val_auc: 0.9707 - val_loss: 0.0494
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9219 - auc: 0.9695 - loss: 0.0502
# Epoch 49: val_auc did not improve from 0.97066
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 233ms/step - accuracy: 0.9235 - auc: 0.9691 - loss: 0.0501 - val_accuracy: 0.9286 - val_auc: 0.9705 - val_loss: 0.0496
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9230 - auc: 0.9701 - loss: 0.0495
# Epoch 50: val_auc did not improve from 0.97066
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 240ms/step - accuracy: 0.9238 - auc: 0.9694 - loss: 0.0498 - val_accuracy: 0.9280 - val_auc: 0.9706 - val_loss: 0.0499
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9268 - auc: 0.9709 - loss: 0.0491
# Epoch 51: val_auc did not improve from 0.97066
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 229ms/step - accuracy: 0.9260 - auc: 0.9703 - loss: 0.0493 - val_accuracy: 0.9264 - val_auc: 0.9704 - val_loss: 0.0496
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9219 - auc: 0.9703 - loss: 0.0494
# Epoch 52: val_auc improved from 0.97066 to 0.97069, saving model to ./model/best_bigru_model.keras
#
# Epoch 52: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 236ms/step - accuracy: 0.9235 - auc: 0.9703 - loss: 0.0494 - val_accuracy: 0.9286 - val_auc: 0.9707 - val_loss: 0.0490
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9236 - auc: 0.9706 - loss: 0.0490
# Epoch 53: val_auc improved from 0.97069 to 0.97087, saving model to ./model/best_bigru_model.keras
#
# Epoch 53: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 218ms/step - accuracy: 0.9246 - auc: 0.9704 - loss: 0.0491 - val_accuracy: 0.9280 - val_auc: 0.9709 - val_loss: 0.0491
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.9227 - auc: 0.9706 - loss: 0.0490
# Epoch 54: val_auc improved from 0.97087 to 0.97121, saving model to ./model/best_bigru_model.keras
#
# Epoch 54: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 243ms/step - accuracy: 0.9253 - auc: 0.9704 - loss: 0.0490 - val_accuracy: 0.9275 - val_auc: 0.9712 - val_loss: 0.0492
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9242 - auc: 0.9702 - loss: 0.0490
# Epoch 55: val_auc did not improve from 0.97121
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 221ms/step - accuracy: 0.9258 - auc: 0.9702 - loss: 0.0491 - val_accuracy: 0.9302 - val_auc: 0.9711 - val_loss: 0.0489
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9224 - auc: 0.9719 - loss: 0.0488
# Epoch 56: val_auc did not improve from 0.97121
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 209ms/step - accuracy: 0.9241 - auc: 0.9714 - loss: 0.0486 - val_accuracy: 0.9269 - val_auc: 0.9711 - val_loss: 0.0493
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9240 - auc: 0.9703 - loss: 0.0493
# Epoch 57: val_auc did not improve from 0.97121
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 219ms/step - accuracy: 0.9254 - auc: 0.9706 - loss: 0.0489 - val_accuracy: 0.9297 - val_auc: 0.9710 - val_loss: 0.0489
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9254 - auc: 0.9726 - loss: 0.0479
# Epoch 58: val_auc did not improve from 0.97121
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 220ms/step - accuracy: 0.9243 - auc: 0.9719 - loss: 0.0484 - val_accuracy: 0.9308 - val_auc: 0.9709 - val_loss: 0.0494
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9252 - auc: 0.9713 - loss: 0.0485
# Epoch 59: val_auc did not improve from 0.97121
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 222ms/step - accuracy: 0.9247 - auc: 0.9717 - loss: 0.0486 - val_accuracy: 0.9302 - val_auc: 0.9711 - val_loss: 0.0497
# Epoch 59: early stopping
# Restoring model weights from the end of the best epoch: 54.
#
# Evaluating model...
#
# TRAINING COMPLETE
# ==================================================
# Model  Accuracy  Precision   Recall      F1  TP  TN  FP  FN Training_Time  Epochs
# BiGRU  0.931806    0.98111 0.884043 0.93005 831 877  16 109       0:08:09      59

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import os

# ==============================
# Directory setup
# ==============================

MODEL_NAME = "BiGRU+CONV"

CSV_PATH = "./csv"
IMAGE_PATH = "./image"

os.makedirs(CSV_PATH, exist_ok=True)
os.makedirs(IMAGE_PATH, exist_ok=True)

METRIC_FILE = os.path.join(CSV_PATH, f"{MODEL_NAME}_metrics.csv")
HISTORY_FILE = os.path.join(CSV_PATH, f"{MODEL_NAME}_training_history.csv")
PLOT_FILE = os.path.join(IMAGE_PATH, f"{MODEL_NAME}_history.png")


# ==============================
# Metrics Class
# ==============================

class ComputeMetrics:
    """Class to compute and manage classification metrics."""

    def __init__(self, y_true, y_pred):
        self.y_true = y_true.flatten() if y_true.ndim > 1 else y_true
        self.y_pred = y_pred.flatten() if y_pred.ndim > 1 else y_pred

    def get_confusion_matrix(self):
        return confusion_matrix(self.y_true, self.y_pred)

    def get_precision(self):
        return precision_score(self.y_true, self.y_pred, zero_division=0)

    def get_recall(self):
        return recall_score(self.y_true, self.y_pred, zero_division=0)

    def get_f1_score(self):
        return f1_score(self.y_true, self.y_pred, zero_division=0)

    def get_accuracy(self):
        return accuracy_score(self.y_true, self.y_pred)

    def get_all_metrics(self):
        cm = self.get_confusion_matrix()
        tn, fp, fn, tp = cm.ravel()

        return {
            "TP": int(tp),
            "TN": int(tn),
            "FP": int(fp),
            "FN": int(fn),
            "Precision": float(self.get_precision()),
            "Recall": float(self.get_recall()),
            "F1-Score": float(self.get_f1_score()),
            "Accuracy": float(self.get_accuracy())
        }


# ==============================
# Predict
# ==============================

y_pred = (model.predict(X_test) > 0.5).astype(int)

metrics_calculator = ComputeMetrics(y_test, y_pred)
metrics = metrics_calculator.get_all_metrics()

print("\n" + "="*50)
print("CLASSIFICATION METRICS ON TEST SET")
print("="*50)

for key, value in metrics.items():
    if isinstance(value, float):
        print(f"{key:12s}: {value:.4f}")
    else:
        print(f"{key:12s}: {value}")


# ==============================
# Save Metrics
# ==============================

metrics_df = pd.DataFrame([metrics])
metrics_df.insert(0, "Model", MODEL_NAME)
metrics_df.to_csv(METRIC_FILE, index=False)

print(f"\n✓ Metrics saved to: {METRIC_FILE}")


# ==============================
# Plot Training History
# ==============================

print("\n" + "="*50)
print("TRAINING HISTORY VISUALIZATION")
print("="*50)

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Accuracy
axes[0].plot(history.history["accuracy"], label="Train Accuracy", linewidth=2)
axes[0].plot(history.history["val_accuracy"], label="Val Accuracy", linewidth=2)

axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Accuracy")
axes[0].set_title("Model Accuracy per Epoch")
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Loss
axes[1].plot(history.history["loss"], label="Train Loss", linewidth=2)
axes[1].plot(history.history["val_loss"], label="Val Loss", linewidth=2)

axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss")
axes[1].set_title("Model Loss per Epoch")
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(PLOT_FILE, dpi=300, bbox_inches="tight")

print(f"✓ Training history plot saved to: {PLOT_FILE}")

plt.show()


# ==============================
# Save Training History CSV
# ==============================

history_df = pd.DataFrame({
    "epoch": range(1, len(history.history["accuracy"]) + 1),
    "train_accuracy": history.history["accuracy"],
    "val_accuracy": history.history["val_accuracy"],
    "train_loss": history.history["loss"],
    "val_loss": history.history["val_loss"]
})

history_df.to_csv(HISTORY_FILE, index=False)

print(f"✓ Training history saved to: {HISTORY_FILE}")
print("="*50)
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step
#
# ==================================================
# CLASSIFICATION METRICS ON TEST SET
# ==================================================
# TP          : 831
# TN          : 877
# FP          : 16
# FN          : 109
# Precision   : 0.9811
# Recall      : 0.8840
# F1-Score    : 0.9301
# Accuracy    : 0.9318
#
# ✓ Metrics saved to: ./csv/BiGRU+CONV_metrics.csv
#
# ==================================================
# TRAINING HISTORY VISUALIZATION
# ==================================================
# ✓ Training history plot saved to: ./image/BiGRU+CONV_history.png
# ✓ Training history saved to: ./csv/BiGRU+CONV_training_history.csv
# ==================================================

# %%
import seaborn as sns
import os
from matplotlib import pyplot as plt

MODEL_NAME = "BiGRU+CONV"

IMAGE_PATH = "./image"
os.makedirs(IMAGE_PATH, exist_ok=True)

CM_FILE = os.path.join(IMAGE_PATH, f"{MODEL_NAME}_confusion_matrix.png")


# ==============================
# Confusion Matrix Visualization
# ==============================

print("\n" + "="*50)
print("CONFUSION MATRIX VISUALIZATION")
print("="*50)

cm = metrics_calculator.get_confusion_matrix()

fig, ax = plt.subplots(figsize=(8,6))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Negative","Positive"],
    yticklabels=["Negative","Positive"],
    cbar_kws={"label":"Count"},
    annot_kws={"size":14},
    ax=ax
)

ax.set_xlabel("Predicted Label", fontsize=12, fontweight="bold")
ax.set_ylabel("True Label", fontsize=12, fontweight="bold")
ax.set_title(f"Confusion Matrix - {MODEL_NAME}", fontsize=14, fontweight="bold")

plt.tight_layout()
plt.savefig(CM_FILE, dpi=300, bbox_inches="tight")

print(f"✓ Confusion matrix saved to: {CM_FILE}")

plt.show()


# ==============================
# Metrics Summary Table
# ==============================

print("\n" + "="*50)
print("METRICS SUMMARY TABLE")
print("="*50)

print(metrics_df.to_string(index=False))

print("="*50)
# Out:
# ==================================================
# CONFUSION MATRIX VISUALIZATION
# ==================================================
# ✓ Confusion matrix saved to: ./image/BiGRU+CONV_confusion_matrix.png
# ==================================================
# METRICS SUMMARY TABLE
# ==================================================
#      Model  TP  TN  FP  FN  Precision   Recall  F1-Score  Accuracy
# BiGRU+CONV 831 877  16 109    0.98111 0.884043   0.93005  0.931806
# ==================================================
