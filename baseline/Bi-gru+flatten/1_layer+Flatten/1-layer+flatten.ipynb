# %%
# load the datapath that has been cleaned and preprocessed 

import pandas as pd

# Dataset paths
DATA_PATHS = {
    "train": "/home/gibannn/kuliah/sem3/paper/SMILES2VEC/code/SMILES/train_set_balanced.xlsx",
    "test":  "/home/gibannn/kuliah/sem3/paper/SMILES2VEC/code/SMILES/test_set_balanced.xlsx",
    "val":   "/home/gibannn/kuliah/sem3/paper/SMILES2VEC/code/SMILES/val_set_balanced.xlsx"
}

print("Datapaths loaded\n")


def load_dataset(path, name):
    """Load dataset and split into features (X) and labels (y)."""
    
    df = pd.read_excel(path)
    
    X = df.drop(columns="labels")
    y = df["labels"]

    print(f"{name.upper()} DATA")
    print(f"X_{name} shape: {X.shape} | y_{name} shape: {y.shape}")
    
    label_dist = y.value_counts().rename(index={0: "Label 0", 1: "Label 1"})
    print("Label distribution:\n", label_dist, "\n")

    return X, y


# Load datasets
X_train, y_train = load_dataset(DATA_PATHS["train"], "train")
X_test, y_test   = load_dataset(DATA_PATHS["test"], "test")
X_val, y_val     = load_dataset(DATA_PATHS["val"], "val")
# Out:
# Datapaths loaded
#
# TRAIN DATA
# X_train shape: (8260, 271) | y_train shape: (8260,)
# Label distribution:
#  labels
# Label 0    4167
# Label 1    4093
# Name: count, dtype: int64
#
# TEST DATA
# X_test shape: (1833, 271) | y_test shape: (1833,)
# Label distribution:
#  labels
# Label 1    940
# Label 0    893
# Name: count, dtype: int64
#
# VAL DATA
# X_val shape: (1806, 271) | y_val shape: (1806,)
# Label distribution:
#  labels
# Label 1    913
# Label 0    893
# Name: count, dtype: int64

# %%
vocab_size = int(
    max(
        X_train.to_numpy().max(),
        X_test.to_numpy().max(),
        X_val.to_numpy().max()
    )
)

# Maximum sequence length
MAX_LEN = X_train.shape[1]

print("Dataset Statistics")
print("------------------")
print(f"Vocabulary size: {vocab_size}")
print(f"Max sequence length: {MAX_LEN}")

print("\nClass distribution in training set (after ADASYN balancing):")
print(
    y_train.value_counts()
    .rename(index={
        0: "Label 0 (Negative)",
        1: "Label 1 (Positive)"
    })
)
# Out:
# Dataset Statistics
# ------------------
# Vocabulary size: 132
# Max sequence length: 271
#
# Class distribution in training set (after ADASYN balancing):
# labels
# Label 0 (Negative)    4167
# Label 1 (Positive)    4093
# Name: count, dtype: int64

# %%
# ================================
# Environment Configuration
# ================================
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"       # Suppress TensorFlow logs
os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"     # Use GPU 0 and 1
os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"      # Disable OneDNN optimizations


# ================================
# Imports
# ================================
import warnings
import random
import time

import numpy as np
import tensorflow as tf
import sklearn.metrics as metrics

warnings.filterwarnings("ignore", category=FutureWarning)


# ================================
# Reproducibility
# ================================
RANDOM_STATE = 116

def set_seeds(seed: int = 116):
    """Set seeds for reproducibility."""
    np.random.seed(seed)
    random.seed(seed)
    tf.random.set_seed(seed)


set_seeds(RANDOM_STATE)


# ================================
# GPU Configuration
# ================================
def setup_gpu():
    """Configure TensorFlow GPU memory growth."""
    
    gpus = tf.config.list_physical_devices("GPU")

    if not gpus:
        print("No GPU detected. Using CPU.")
        return

    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)

        logical_gpus = tf.config.list_logical_devices("GPU")

        print(f"GPUs available: {len(gpus)} physical | {len(logical_gpus)} logical")

    except RuntimeError as e:
        print("GPU setup failed:", e)


setup_gpu()


# ================================
# Training Configuration
# ================================
def set_training_config(batch_size=256, iterations=128, epochs=100):
    """Define training hyperparameters."""
    
    config = {
        "BATCH_SIZE": batch_size,
        "ITERATIONS": iterations,
        "EPOCHS": epochs
    }

    return config


TRAIN_CONFIG = set_training_config()

BATCH_SIZE = TRAIN_CONFIG["BATCH_SIZE"]
ITERATIONS = TRAIN_CONFIG["ITERATIONS"]
EPOCHS = TRAIN_CONFIG["EPOCHS"]

print(f"Training config -> Batch: {BATCH_SIZE} | Iterations: {ITERATIONS} | Epochs: {EPOCHS}")
# Out:
# /home/gibannn/miniconda3/envs/RISET-SMILES/lib/python3.11/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# GPUs available: 1 physical | 1 logical
# Training config -> Batch: 256 | Iterations: 128 | Epochs: 100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773715387.454912   81131 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5560 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:65:00.0, compute capability: 8.9

# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Embedding, Conv1D, BatchNormalization,
    MaxPooling1D, GRU, Bidirectional,
    Dense, Dropout , Flatten
)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import plot_model



# Paths (simple and portable)

MODEL_DIR = "./model"
IMAGE_DIR = "./image"

os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(IMAGE_DIR, exist_ok=True)

MODEL_FILE = os.path.join(MODEL_DIR, "best_bigru_conv_model.h5")
MODEL_IMAGE = os.path.join(IMAGE_DIR, "bigru_conv_architecture.png")



# Model Architecture

def build_bigru_conv_model(sequence_length, vocabulary_size):

    set_seeds(RANDOM_STATE)

    model = Sequential([

        # Embedding
        Embedding(
            input_dim=vocabulary_size + 1,
            output_dim=128,
            mask_zero=False
        ),

        # Bidirectional GRU
        Bidirectional(
            GRU(
                32,
                return_sequences=False,
                dropout=0.3
            )
        ),
        

        #adding flatten layer
        Flatten(),
        # Output layer
        Dense(1, activation="sigmoid")
    ])

    return model



# Build Model

model = build_bigru_conv_model(MAX_LEN, vocab_size)

loss = tf.keras.losses.BinaryFocalCrossentropy(gamma=2)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss=loss,
    metrics=[
        "accuracy",
        tf.keras.metrics.AUC(name="auc")
    ]
)

model.build(input_shape=(None, MAX_LEN))

print("Model built successfully")
model.summary()



# Callbacks

early_stopping = EarlyStopping(
    monitor="val_auc",
    mode="max",
    patience=3,
    restore_best_weights=True,
    verbose=1
)

model_checkpoint = ModelCheckpoint(
    filepath=MODEL_FILE,
    monitor="val_auc",
    mode="max",
    save_best_only=True,
    verbose=1
)


# Save Model Architecture Diagram
plot_model(
    model,
    to_file=MODEL_IMAGE,
    show_shapes=True,
    show_layer_names=True
)

print(f"Model diagram saved to: {MODEL_IMAGE}")
# Out:
# /home/gibannn/miniconda3/envs/RISET-SMILES/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model built successfully
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 271, 128)       │        17,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 64)             │        31,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 48,193 (188.25 KB)
#  Trainable params: 48,193 (188.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Model diagram saved to: ./image/bigru_conv_architecture.png

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score

def compute_classification_metrics(y_true, y_pred):
    """
    Returns TP, TN, FP, FN, Precision, Recall, F1, Accuracy
    """
    cm = confusion_matrix(y_true, y_pred)
    
    tn, fp, fn, tp = cm.ravel()

    precision = precision_score(y_true, y_pred, zero_division=0)
    recall    = recall_score(y_true, y_pred, zero_division=0)
    f1        = f1_score(y_true, y_pred, zero_division=0)
    accuracy  = accuracy_score(y_true, y_pred)

    return {
        "TP": tp,
        "TN": tn,
        "FP": fp,
        "FN": fn,
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1,
        "Accuracy": accuracy
    }

print("the function to compute classification metrics have been defined")
# Out:
# the function to compute classification metrics have been defined

# %%
import os
import time
import pandas as pd
import numpy as np
import tensorflow as tf
from datetime import timedelta
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


def to_numpy(x):
    """Convert pandas objects to numpy arrays."""
    return x.values if hasattr(x, "values") else x


def train_and_evaluate_model(
    X_train, y_train,
    X_val, y_val,
    X_test, y_test,
    epochs=100,
    batch_size=128,
    learning_rate=3e-4,
    model_name="BiGRU+CNN",
    model_save_path="./model/best_model.keras",
    patience=5,
    verbose=1
):
    """
    Train and evaluate sequence classification model.
    """

    print(f"TRAINING {model_name}")
    print("=" * 50)

    start_time = time.time()

    # Convert datasets
    X_train, y_train = to_numpy(X_train), to_numpy(y_train)
    X_val, y_val = to_numpy(X_val), to_numpy(y_val)
    X_test, y_test = to_numpy(X_test), to_numpy(y_test)

    
    # Build model
    
    print("\nBuilding model...")
    model = build_bigru_conv_model(MAX_LEN, vocab_size)

    
    # Compile
    
    print("[2/4] Compiling model...")

    loss_fn = tf.keras.losses.BinaryFocalCrossentropy(gamma=2)

    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss=loss_fn,
        metrics=[
            "accuracy",
            tf.keras.metrics.AUC(name="auc")
        ]
    )

    model.build(input_shape=(None, MAX_LEN))

    if verbose:
        model.summary()

    
    # Callbacks
    
    os.makedirs(os.path.dirname(model_save_path), exist_ok=True)

    callbacks = [

        EarlyStopping(
            monitor="val_auc",
            mode="max",
            patience=patience,
            restore_best_weights=True,
            verbose=1
        ),

        ModelCheckpoint(
            filepath=model_save_path,
            monitor="val_auc",
            mode="max",
            save_best_only=True,
            verbose=1
        )
    ]

    
    # Training
    
    print("\nTraining model...")
    print(f"Epochs: {epochs}")
    print(f"Batch size: {batch_size}")
    print(f"Training samples: {len(X_train)}")

    history = model.fit(
        X_train,
        y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=callbacks,
        verbose=verbose
    )

    training_time = time.time() - start_time

    
    # Evaluation
    
    print("\nEvaluating model...")

    y_pred_prob = model.predict(X_test, verbose=0)
    y_pred = (y_pred_prob > 0.5).astype(int)

    metrics_dict = compute_classification_metrics(y_test, y_pred)

    results_df = pd.DataFrame([{
        "Model": model_name,
        "Accuracy": metrics_dict["Accuracy"],
        "Precision": metrics_dict["Precision"],
        "Recall": metrics_dict["Recall"],
        "F1": metrics_dict["F1-Score"],
        "TP": metrics_dict["TP"],
        "TN": metrics_dict["TN"],
        "FP": metrics_dict["FP"],
        "FN": metrics_dict["FN"],
        "Training_Time": str(timedelta(seconds=int(training_time))),
        "Epochs": len(history.history["loss"])
    }])

    print("\nTRAINING COMPLETE")
    print("=" * 50)
    print(results_df.to_string(index=False))

    return model, history, results_df

# %%
model, history, results = train_and_evaluate_model(
    X_train,
    y_train,
    X_val,
    y_val,
    X_test,
    y_test,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    model_name="BiGRU",
    model_save_path="./model/best_bigru_model.keras"
)
# Out:
# TRAINING BiGRU
# ==================================================
#
# Building model...
# [2/4] Compiling model...
# /home/gibannn/miniconda3/envs/RISET-SMILES/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 271, 128)       │        17,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 64)             │        31,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 48,193 (188.25 KB)
#  Trainable params: 48,193 (188.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Training model...
# Epochs: 100
# Batch size: 256
# Training samples: 8260
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.6488 - auc: 0.7079 - loss: 0.1628
# Epoch 1: val_auc improved from None to 0.86990, saving model to ./model/best_bigru_model.keras
#
# Epoch 1: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 17s 236ms/step - accuracy: 0.7219 - auc: 0.8038 - loss: 0.1516 - val_accuracy: 0.7763 - val_auc: 0.8699 - val_loss: 0.1270
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7936 - auc: 0.8673 - loss: 0.1212
# Epoch 2: val_auc improved from 0.86990 to 0.90594, saving model to ./model/best_bigru_model.keras
#
# Epoch 2: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - accuracy: 0.8029 - auc: 0.8724 - loss: 0.1159 - val_accuracy: 0.8355 - val_auc: 0.9059 - val_loss: 0.0999
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8360 - auc: 0.9009 - loss: 0.1000
# Epoch 3: val_auc improved from 0.90594 to 0.93513, saving model to ./model/best_bigru_model.keras
#
# Epoch 3: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.8421 - auc: 0.9052 - loss: 0.0969 - val_accuracy: 0.8704 - val_auc: 0.9351 - val_loss: 0.0793
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8745 - auc: 0.9315 - loss: 0.0803
# Epoch 4: val_auc improved from 0.93513 to 0.95403, saving model to ./model/best_bigru_model.keras
#
# Epoch 4: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.8805 - auc: 0.9349 - loss: 0.0769 - val_accuracy: 0.9059 - val_auc: 0.9540 - val_loss: 0.0619
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9029 - auc: 0.9494 - loss: 0.0653
# Epoch 5: val_auc improved from 0.95403 to 0.95795, saving model to ./model/best_bigru_model.keras
#
# Epoch 5: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9040 - auc: 0.9488 - loss: 0.0656 - val_accuracy: 0.9092 - val_auc: 0.9579 - val_loss: 0.0586
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9074 - auc: 0.9520 - loss: 0.0625
# Epoch 6: val_auc improved from 0.95795 to 0.95823, saving model to ./model/best_bigru_model.keras
#
# Epoch 6: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - accuracy: 0.9085 - auc: 0.9508 - loss: 0.0633 - val_accuracy: 0.9169 - val_auc: 0.9582 - val_loss: 0.0572
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9120 - auc: 0.9521 - loss: 0.0613
# Epoch 7: val_auc did not improve from 0.95823
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.9122 - auc: 0.9514 - loss: 0.0619 - val_accuracy: 0.9164 - val_auc: 0.9580 - val_loss: 0.0571
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9090 - auc: 0.9521 - loss: 0.0609
# Epoch 8: val_auc improved from 0.95823 to 0.95841, saving model to ./model/best_bigru_model.keras
#
# Epoch 8: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9116 - auc: 0.9519 - loss: 0.0614 - val_accuracy: 0.9186 - val_auc: 0.9584 - val_loss: 0.0576
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9130 - auc: 0.9520 - loss: 0.0609
# Epoch 9: val_auc improved from 0.95841 to 0.95846, saving model to ./model/best_bigru_model.keras
#
# Epoch 9: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - accuracy: 0.9128 - auc: 0.9523 - loss: 0.0613 - val_accuracy: 0.9153 - val_auc: 0.9585 - val_loss: 0.0567
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9098 - auc: 0.9521 - loss: 0.0606
# Epoch 10: val_auc improved from 0.95846 to 0.95847, saving model to ./model/best_bigru_model.keras
#
# Epoch 10: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9121 - auc: 0.9523 - loss: 0.0607 - val_accuracy: 0.9203 - val_auc: 0.9585 - val_loss: 0.0572
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9134 - auc: 0.9535 - loss: 0.0594
# Epoch 11: val_auc improved from 0.95847 to 0.95916, saving model to ./model/best_bigru_model.keras
#
# Epoch 11: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - accuracy: 0.9144 - auc: 0.9538 - loss: 0.0596 - val_accuracy: 0.9192 - val_auc: 0.9592 - val_loss: 0.0571
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9147 - auc: 0.9541 - loss: 0.0596
# Epoch 12: val_auc improved from 0.95916 to 0.95943, saving model to ./model/best_bigru_model.keras
#
# Epoch 12: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.9151 - auc: 0.9539 - loss: 0.0602 - val_accuracy: 0.9214 - val_auc: 0.9594 - val_loss: 0.0569
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9145 - auc: 0.9539 - loss: 0.0600
# Epoch 13: val_auc did not improve from 0.95943
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - accuracy: 0.9157 - auc: 0.9534 - loss: 0.0600 - val_accuracy: 0.9225 - val_auc: 0.9594 - val_loss: 0.0569
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9152 - auc: 0.9541 - loss: 0.0601
# Epoch 14: val_auc improved from 0.95943 to 0.95997, saving model to ./model/best_bigru_model.keras
#
# Epoch 14: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.9143 - auc: 0.9545 - loss: 0.0599 - val_accuracy: 0.9169 - val_auc: 0.9600 - val_loss: 0.0567
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9133 - auc: 0.9548 - loss: 0.0588
# Epoch 15: val_auc improved from 0.95997 to 0.96024, saving model to ./model/best_bigru_model.keras
#
# Epoch 15: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 219ms/step - accuracy: 0.9145 - auc: 0.9550 - loss: 0.0589 - val_accuracy: 0.9208 - val_auc: 0.9602 - val_loss: 0.0562
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9144 - auc: 0.9552 - loss: 0.0585
# Epoch 16: val_auc improved from 0.96024 to 0.96049, saving model to ./model/best_bigru_model.keras
#
# Epoch 16: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - accuracy: 0.9151 - auc: 0.9555 - loss: 0.0585 - val_accuracy: 0.9197 - val_auc: 0.9605 - val_loss: 0.0560
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9161 - auc: 0.9558 - loss: 0.0581
# Epoch 17: val_auc improved from 0.96049 to 0.96083, saving model to ./model/best_bigru_model.keras
#
# Epoch 17: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 210ms/step - accuracy: 0.9169 - auc: 0.9559 - loss: 0.0582 - val_accuracy: 0.9203 - val_auc: 0.9608 - val_loss: 0.0559
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9180 - auc: 0.9554 - loss: 0.0582
# Epoch 18: val_auc improved from 0.96083 to 0.96093, saving model to ./model/best_bigru_model.keras
#
# Epoch 18: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - accuracy: 0.9169 - auc: 0.9559 - loss: 0.0583 - val_accuracy: 0.9192 - val_auc: 0.9609 - val_loss: 0.0557
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9160 - auc: 0.9569 - loss: 0.0576
# Epoch 19: val_auc improved from 0.96093 to 0.96145, saving model to ./model/best_bigru_model.keras
#
# Epoch 19: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - accuracy: 0.9165 - auc: 0.9569 - loss: 0.0577 - val_accuracy: 0.9203 - val_auc: 0.9614 - val_loss: 0.0553
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9143 - auc: 0.9570 - loss: 0.0575
# Epoch 20: val_auc improved from 0.96145 to 0.96175, saving model to ./model/best_bigru_model.keras
#
# Epoch 20: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 187ms/step - accuracy: 0.9162 - auc: 0.9574 - loss: 0.0573 - val_accuracy: 0.9219 - val_auc: 0.9618 - val_loss: 0.0552
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9175 - auc: 0.9566 - loss: 0.0573
# Epoch 21: val_auc improved from 0.96175 to 0.96181, saving model to ./model/best_bigru_model.keras
#
# Epoch 21: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 200ms/step - accuracy: 0.9173 - auc: 0.9571 - loss: 0.0573 - val_accuracy: 0.9214 - val_auc: 0.9618 - val_loss: 0.0550
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9167 - auc: 0.9570 - loss: 0.0570
# Epoch 22: val_auc improved from 0.96181 to 0.96208, saving model to ./model/best_bigru_model.keras
#
# Epoch 22: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9177 - auc: 0.9573 - loss: 0.0571 - val_accuracy: 0.9225 - val_auc: 0.9621 - val_loss: 0.0548
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9191 - auc: 0.9582 - loss: 0.0566
# Epoch 23: val_auc improved from 0.96208 to 0.96210, saving model to ./model/best_bigru_model.keras
#
# Epoch 23: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 200ms/step - accuracy: 0.9184 - auc: 0.9579 - loss: 0.0569 - val_accuracy: 0.9214 - val_auc: 0.9621 - val_loss: 0.0548
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9180 - auc: 0.9579 - loss: 0.0566
# Epoch 24: val_auc improved from 0.96210 to 0.96231, saving model to ./model/best_bigru_model.keras
#
# Epoch 24: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 186ms/step - accuracy: 0.9182 - auc: 0.9577 - loss: 0.0569 - val_accuracy: 0.9230 - val_auc: 0.9623 - val_loss: 0.0545
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9178 - auc: 0.9587 - loss: 0.0566
# Epoch 25: val_auc improved from 0.96231 to 0.96267, saving model to ./model/best_bigru_model.keras
#
# Epoch 25: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - accuracy: 0.9177 - auc: 0.9585 - loss: 0.0567 - val_accuracy: 0.9241 - val_auc: 0.9627 - val_loss: 0.0543
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9195 - auc: 0.9593 - loss: 0.0559
# Epoch 26: val_auc improved from 0.96267 to 0.96272, saving model to ./model/best_bigru_model.keras
#
# Epoch 26: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - accuracy: 0.9195 - auc: 0.9587 - loss: 0.0562 - val_accuracy: 0.9230 - val_auc: 0.9627 - val_loss: 0.0542
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9176 - auc: 0.9597 - loss: 0.0558
# Epoch 27: val_auc improved from 0.96272 to 0.96314, saving model to ./model/best_bigru_model.keras
#
# Epoch 27: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - accuracy: 0.9188 - auc: 0.9595 - loss: 0.0559 - val_accuracy: 0.9225 - val_auc: 0.9631 - val_loss: 0.0541
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9188 - auc: 0.9594 - loss: 0.0561
# Epoch 28: val_auc did not improve from 0.96314
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 204ms/step - accuracy: 0.9190 - auc: 0.9590 - loss: 0.0563 - val_accuracy: 0.9236 - val_auc: 0.9628 - val_loss: 0.0533
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9175 - auc: 0.9597 - loss: 0.0558
# Epoch 29: val_auc improved from 0.96314 to 0.96356, saving model to ./model/best_bigru_model.keras
#
# Epoch 29: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9186 - auc: 0.9597 - loss: 0.0558 - val_accuracy: 0.9241 - val_auc: 0.9636 - val_loss: 0.0539
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9185 - auc: 0.9602 - loss: 0.0554
# Epoch 30: val_auc improved from 0.96356 to 0.96372, saving model to ./model/best_bigru_model.keras
#
# Epoch 30: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - accuracy: 0.9189 - auc: 0.9599 - loss: 0.0557 - val_accuracy: 0.9247 - val_auc: 0.9637 - val_loss: 0.0533
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9180 - auc: 0.9608 - loss: 0.0554
# Epoch 31: val_auc improved from 0.96372 to 0.96376, saving model to ./model/best_bigru_model.keras
#
# Epoch 31: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 186ms/step - accuracy: 0.9183 - auc: 0.9610 - loss: 0.0553 - val_accuracy: 0.9247 - val_auc: 0.9638 - val_loss: 0.0536
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9211 - auc: 0.9617 - loss: 0.0545
# Epoch 32: val_auc improved from 0.96376 to 0.96383, saving model to ./model/best_bigru_model.keras
#
# Epoch 32: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - accuracy: 0.9219 - auc: 0.9611 - loss: 0.0549 - val_accuracy: 0.9258 - val_auc: 0.9638 - val_loss: 0.0534
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9213 - auc: 0.9614 - loss: 0.0546
# Epoch 33: val_auc did not improve from 0.96383
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - accuracy: 0.9208 - auc: 0.9615 - loss: 0.0547 - val_accuracy: 0.9252 - val_auc: 0.9638 - val_loss: 0.0533
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9200 - auc: 0.9622 - loss: 0.0543
# Epoch 34: val_auc improved from 0.96383 to 0.96396, saving model to ./model/best_bigru_model.keras
#
# Epoch 34: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 188ms/step - accuracy: 0.9201 - auc: 0.9617 - loss: 0.0547 - val_accuracy: 0.9252 - val_auc: 0.9640 - val_loss: 0.0532
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9202 - auc: 0.9618 - loss: 0.0546
# Epoch 35: val_auc improved from 0.96396 to 0.96433, saving model to ./model/best_bigru_model.keras
#
# Epoch 35: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 186ms/step - accuracy: 0.9197 - auc: 0.9614 - loss: 0.0548 - val_accuracy: 0.9258 - val_auc: 0.9643 - val_loss: 0.0530
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9205 - auc: 0.9620 - loss: 0.0543
# Epoch 36: val_auc improved from 0.96433 to 0.96445, saving model to ./model/best_bigru_model.keras
#
# Epoch 36: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - accuracy: 0.9205 - auc: 0.9620 - loss: 0.0544 - val_accuracy: 0.9258 - val_auc: 0.9645 - val_loss: 0.0530
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9194 - auc: 0.9627 - loss: 0.0542
# Epoch 37: val_auc improved from 0.96445 to 0.96446, saving model to ./model/best_bigru_model.keras
#
# Epoch 37: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9205 - auc: 0.9622 - loss: 0.0543 - val_accuracy: 0.9241 - val_auc: 0.9645 - val_loss: 0.0523
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9168 - auc: 0.9631 - loss: 0.0542
# Epoch 38: val_auc improved from 0.96446 to 0.96455, saving model to ./model/best_bigru_model.keras
#
# Epoch 38: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - accuracy: 0.9180 - auc: 0.9624 - loss: 0.0542 - val_accuracy: 0.9269 - val_auc: 0.9646 - val_loss: 0.0526
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9205 - auc: 0.9636 - loss: 0.0535
# Epoch 39: val_auc improved from 0.96455 to 0.96470, saving model to ./model/best_bigru_model.keras
#
# Epoch 39: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9209 - auc: 0.9633 - loss: 0.0537 - val_accuracy: 0.9269 - val_auc: 0.9647 - val_loss: 0.0524
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9201 - auc: 0.9637 - loss: 0.0534
# Epoch 40: val_auc improved from 0.96470 to 0.96494, saving model to ./model/best_bigru_model.keras
#
# Epoch 40: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - accuracy: 0.9213 - auc: 0.9634 - loss: 0.0536 - val_accuracy: 0.9264 - val_auc: 0.9649 - val_loss: 0.0524
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9206 - auc: 0.9638 - loss: 0.0533
# Epoch 41: val_auc improved from 0.96494 to 0.96509, saving model to ./model/best_bigru_model.keras
#
# Epoch 41: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 186ms/step - accuracy: 0.9214 - auc: 0.9638 - loss: 0.0535 - val_accuracy: 0.9269 - val_auc: 0.9651 - val_loss: 0.0526
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9209 - auc: 0.9634 - loss: 0.0535
# Epoch 42: val_auc did not improve from 0.96509
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 196ms/step - accuracy: 0.9211 - auc: 0.9628 - loss: 0.0538 - val_accuracy: 0.9258 - val_auc: 0.9650 - val_loss: 0.0522
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9213 - auc: 0.9642 - loss: 0.0532
# Epoch 43: val_auc improved from 0.96509 to 0.96517, saving model to ./model/best_bigru_model.keras
#
# Epoch 43: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 11s 206ms/step - accuracy: 0.9218 - auc: 0.9637 - loss: 0.0534 - val_accuracy: 0.9269 - val_auc: 0.9652 - val_loss: 0.0522
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9219 - auc: 0.9648 - loss: 0.0525
# Epoch 44: val_auc improved from 0.96517 to 0.96525, saving model to ./model/best_bigru_model.keras
#
# Epoch 44: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.9229 - auc: 0.9637 - loss: 0.0531 - val_accuracy: 0.9258 - val_auc: 0.9653 - val_loss: 0.0519
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9235 - auc: 0.9651 - loss: 0.0523
# Epoch 45: val_auc improved from 0.96525 to 0.96525, saving model to ./model/best_bigru_model.keras
#
# Epoch 45: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - accuracy: 0.9222 - auc: 0.9645 - loss: 0.0528 - val_accuracy: 0.9258 - val_auc: 0.9653 - val_loss: 0.0522
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9230 - auc: 0.9642 - loss: 0.0533
# Epoch 46: val_auc did not improve from 0.96525
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - accuracy: 0.9222 - auc: 0.9626 - loss: 0.0542 - val_accuracy: 0.9252 - val_auc: 0.9645 - val_loss: 0.0526
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9187 - auc: 0.9636 - loss: 0.0538
# Epoch 47: val_auc improved from 0.96525 to 0.96529, saving model to ./model/best_bigru_model.keras
#
# Epoch 47: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - accuracy: 0.9207 - auc: 0.9639 - loss: 0.0534 - val_accuracy: 0.9275 - val_auc: 0.9653 - val_loss: 0.0515
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9228 - auc: 0.9657 - loss: 0.0522
# Epoch 48: val_auc improved from 0.96529 to 0.96553, saving model to ./model/best_bigru_model.keras
#
# Epoch 48: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 183ms/step - accuracy: 0.9226 - auc: 0.9655 - loss: 0.0524 - val_accuracy: 0.9264 - val_auc: 0.9655 - val_loss: 0.0514
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9197 - auc: 0.9652 - loss: 0.0524
# Epoch 49: val_auc improved from 0.96553 to 0.96566, saving model to ./model/best_bigru_model.keras
#
# Epoch 49: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 193ms/step - accuracy: 0.9205 - auc: 0.9648 - loss: 0.0528 - val_accuracy: 0.9252 - val_auc: 0.9657 - val_loss: 0.0514
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9217 - auc: 0.9661 - loss: 0.0519
# Epoch 50: val_auc improved from 0.96566 to 0.96608, saving model to ./model/best_bigru_model.keras
#
# Epoch 50: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 196ms/step - accuracy: 0.9218 - auc: 0.9655 - loss: 0.0523 - val_accuracy: 0.9252 - val_auc: 0.9661 - val_loss: 0.0511
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9230 - auc: 0.9660 - loss: 0.0518
# Epoch 51: val_auc did not improve from 0.96608
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9235 - auc: 0.9657 - loss: 0.0520 - val_accuracy: 0.9258 - val_auc: 0.9659 - val_loss: 0.0518
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9239 - auc: 0.9657 - loss: 0.0519
# Epoch 52: val_auc improved from 0.96608 to 0.96609, saving model to ./model/best_bigru_model.keras
#
# Epoch 52: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 193ms/step - accuracy: 0.9235 - auc: 0.9654 - loss: 0.0521 - val_accuracy: 0.9269 - val_auc: 0.9661 - val_loss: 0.0515
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9225 - auc: 0.9669 - loss: 0.0514
# Epoch 53: val_auc improved from 0.96609 to 0.96610, saving model to ./model/best_bigru_model.keras
#
# Epoch 53: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 198ms/step - accuracy: 0.9224 - auc: 0.9660 - loss: 0.0520 - val_accuracy: 0.9264 - val_auc: 0.9661 - val_loss: 0.0513
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9239 - auc: 0.9665 - loss: 0.0514
# Epoch 54: val_auc improved from 0.96610 to 0.96620, saving model to ./model/best_bigru_model.keras
#
# Epoch 54: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 198ms/step - accuracy: 0.9241 - auc: 0.9658 - loss: 0.0518 - val_accuracy: 0.9264 - val_auc: 0.9662 - val_loss: 0.0513
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9237 - auc: 0.9671 - loss: 0.0512
# Epoch 55: val_auc improved from 0.96620 to 0.96623, saving model to ./model/best_bigru_model.keras
#
# Epoch 55: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 193ms/step - accuracy: 0.9246 - auc: 0.9661 - loss: 0.0516 - val_accuracy: 0.9252 - val_auc: 0.9662 - val_loss: 0.0513
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9226 - auc: 0.9665 - loss: 0.0514
# Epoch 56: val_auc improved from 0.96623 to 0.96636, saving model to ./model/best_bigru_model.keras
#
# Epoch 56: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9231 - auc: 0.9663 - loss: 0.0516 - val_accuracy: 0.9258 - val_auc: 0.9664 - val_loss: 0.0512
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9244 - auc: 0.9672 - loss: 0.0509
# Epoch 57: val_auc improved from 0.96636 to 0.96638, saving model to ./model/best_bigru_model.keras
#
# Epoch 57: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - accuracy: 0.9247 - auc: 0.9666 - loss: 0.0513 - val_accuracy: 0.9264 - val_auc: 0.9664 - val_loss: 0.0507
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9244 - auc: 0.9674 - loss: 0.0508
# Epoch 58: val_auc improved from 0.96638 to 0.96655, saving model to ./model/best_bigru_model.keras
#
# Epoch 58: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - accuracy: 0.9254 - auc: 0.9667 - loss: 0.0512 - val_accuracy: 0.9252 - val_auc: 0.9665 - val_loss: 0.0508
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9230 - auc: 0.9674 - loss: 0.0508
# Epoch 59: val_auc did not improve from 0.96655
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.9245 - auc: 0.9668 - loss: 0.0513 - val_accuracy: 0.9225 - val_auc: 0.9665 - val_loss: 0.0512
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9228 - auc: 0.9670 - loss: 0.0511
# Epoch 60: val_auc improved from 0.96655 to 0.96676, saving model to ./model/best_bigru_model.keras
#
# Epoch 60: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 197ms/step - accuracy: 0.9236 - auc: 0.9664 - loss: 0.0514 - val_accuracy: 0.9264 - val_auc: 0.9668 - val_loss: 0.0503
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9237 - auc: 0.9673 - loss: 0.0508
# Epoch 61: val_auc did not improve from 0.96676
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 178ms/step - accuracy: 0.9236 - auc: 0.9669 - loss: 0.0511 - val_accuracy: 0.9247 - val_auc: 0.9666 - val_loss: 0.0507
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9222 - auc: 0.9676 - loss: 0.0508
# Epoch 62: val_auc improved from 0.96676 to 0.96698, saving model to ./model/best_bigru_model.keras
#
# Epoch 62: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - accuracy: 0.9241 - auc: 0.9670 - loss: 0.0512 - val_accuracy: 0.9252 - val_auc: 0.9670 - val_loss: 0.0505
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9252 - auc: 0.9685 - loss: 0.0503
# Epoch 63: val_auc improved from 0.96698 to 0.96705, saving model to ./model/best_bigru_model.keras
#
# Epoch 63: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 184ms/step - accuracy: 0.9249 - auc: 0.9675 - loss: 0.0508 - val_accuracy: 0.9247 - val_auc: 0.9670 - val_loss: 0.0504
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9254 - auc: 0.9686 - loss: 0.0498
# Epoch 64: val_auc did not improve from 0.96705
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9253 - auc: 0.9675 - loss: 0.0505 - val_accuracy: 0.9236 - val_auc: 0.9669 - val_loss: 0.0504
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9240 - auc: 0.9686 - loss: 0.0500
# Epoch 65: val_auc improved from 0.96705 to 0.96726, saving model to ./model/best_bigru_model.keras
#
# Epoch 65: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - accuracy: 0.9253 - auc: 0.9680 - loss: 0.0504 - val_accuracy: 0.9252 - val_auc: 0.9673 - val_loss: 0.0500
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9259 - auc: 0.9693 - loss: 0.0497
# Epoch 66: val_auc improved from 0.96726 to 0.96766, saving model to ./model/best_bigru_model.keras
#
# Epoch 66: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - accuracy: 0.9247 - auc: 0.9686 - loss: 0.0500 - val_accuracy: 0.9241 - val_auc: 0.9677 - val_loss: 0.0499
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9245 - auc: 0.9687 - loss: 0.0500
# Epoch 67: val_auc improved from 0.96766 to 0.96787, saving model to ./model/best_bigru_model.keras
#
# Epoch 67: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.9255 - auc: 0.9677 - loss: 0.0505 - val_accuracy: 0.9264 - val_auc: 0.9679 - val_loss: 0.0498
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9251 - auc: 0.9682 - loss: 0.0502
# Epoch 68: val_auc improved from 0.96787 to 0.96790, saving model to ./model/best_bigru_model.keras
#
# Epoch 68: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 206ms/step - accuracy: 0.9253 - auc: 0.9680 - loss: 0.0503 - val_accuracy: 0.9258 - val_auc: 0.9679 - val_loss: 0.0497
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9243 - auc: 0.9690 - loss: 0.0498
# Epoch 69: val_auc improved from 0.96790 to 0.96804, saving model to ./model/best_bigru_model.keras
#
# Epoch 69: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9248 - auc: 0.9688 - loss: 0.0499 - val_accuracy: 0.9258 - val_auc: 0.9680 - val_loss: 0.0496
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9248 - auc: 0.9693 - loss: 0.0496
# Epoch 70: val_auc improved from 0.96804 to 0.96817, saving model to ./model/best_bigru_model.keras
#
# Epoch 70: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - accuracy: 0.9249 - auc: 0.9684 - loss: 0.0501 - val_accuracy: 0.9275 - val_auc: 0.9682 - val_loss: 0.0494
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9231 - auc: 0.9697 - loss: 0.0494
# Epoch 71: val_auc improved from 0.96817 to 0.96835, saving model to ./model/best_bigru_model.keras
#
# Epoch 71: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.9249 - auc: 0.9690 - loss: 0.0496 - val_accuracy: 0.9269 - val_auc: 0.9684 - val_loss: 0.0494
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9230 - auc: 0.9690 - loss: 0.0495
# Epoch 72: val_auc improved from 0.96835 to 0.96842, saving model to ./model/best_bigru_model.keras
#
# Epoch 72: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.9242 - auc: 0.9688 - loss: 0.0497 - val_accuracy: 0.9269 - val_auc: 0.9684 - val_loss: 0.0494
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9238 - auc: 0.9695 - loss: 0.0494
# Epoch 73: val_auc improved from 0.96842 to 0.96865, saving model to ./model/best_bigru_model.keras
#
# Epoch 73: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - accuracy: 0.9247 - auc: 0.9688 - loss: 0.0497 - val_accuracy: 0.9286 - val_auc: 0.9686 - val_loss: 0.0492
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9264 - auc: 0.9696 - loss: 0.0495
# Epoch 74: val_auc did not improve from 0.96865
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - accuracy: 0.9272 - auc: 0.9685 - loss: 0.0503 - val_accuracy: 0.9241 - val_auc: 0.9677 - val_loss: 0.0510
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9214 - auc: 0.9678 - loss: 0.0514
# Epoch 75: val_auc did not improve from 0.96865
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 184ms/step - accuracy: 0.9230 - auc: 0.9678 - loss: 0.0507 - val_accuracy: 0.9252 - val_auc: 0.9684 - val_loss: 0.0495
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9213 - auc: 0.9706 - loss: 0.0492
# Epoch 76: val_auc improved from 0.96865 to 0.96889, saving model to ./model/best_bigru_model.keras
#
# Epoch 76: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 193ms/step - accuracy: 0.9225 - auc: 0.9699 - loss: 0.0495 - val_accuracy: 0.9247 - val_auc: 0.9689 - val_loss: 0.0492
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9249 - auc: 0.9700 - loss: 0.0492
# Epoch 77: val_auc improved from 0.96889 to 0.96927, saving model to ./model/best_bigru_model.keras
#
# Epoch 77: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - accuracy: 0.9251 - auc: 0.9695 - loss: 0.0494 - val_accuracy: 0.9252 - val_auc: 0.9693 - val_loss: 0.0490
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9236 - auc: 0.9706 - loss: 0.0490
# Epoch 78: val_auc improved from 0.96927 to 0.96929, saving model to ./model/best_bigru_model.keras
#
# Epoch 78: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - accuracy: 0.9252 - auc: 0.9698 - loss: 0.0493 - val_accuracy: 0.9264 - val_auc: 0.9693 - val_loss: 0.0488
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9250 - auc: 0.9702 - loss: 0.0490
# Epoch 79: val_auc improved from 0.96929 to 0.96965, saving model to ./model/best_bigru_model.keras
#
# Epoch 79: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 200ms/step - accuracy: 0.9260 - auc: 0.9696 - loss: 0.0493 - val_accuracy: 0.9264 - val_auc: 0.9697 - val_loss: 0.0486
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9258 - auc: 0.9703 - loss: 0.0488
# Epoch 80: val_auc improved from 0.96965 to 0.96992, saving model to ./model/best_bigru_model.keras
#
# Epoch 80: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - accuracy: 0.9260 - auc: 0.9701 - loss: 0.0490 - val_accuracy: 0.9252 - val_auc: 0.9699 - val_loss: 0.0486
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9246 - auc: 0.9703 - loss: 0.0489
# Epoch 81: val_auc improved from 0.96992 to 0.97015, saving model to ./model/best_bigru_model.keras
#
# Epoch 81: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9253 - auc: 0.9696 - loss: 0.0493 - val_accuracy: 0.9269 - val_auc: 0.9702 - val_loss: 0.0484
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9255 - auc: 0.9705 - loss: 0.0489
# Epoch 82: val_auc did not improve from 0.97015
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9257 - auc: 0.9704 - loss: 0.0488 - val_accuracy: 0.9264 - val_auc: 0.9700 - val_loss: 0.0485
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9264 - auc: 0.9708 - loss: 0.0486
# Epoch 83: val_auc improved from 0.97015 to 0.97037, saving model to ./model/best_bigru_model.keras
#
# Epoch 83: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9263 - auc: 0.9707 - loss: 0.0486 - val_accuracy: 0.9275 - val_auc: 0.9704 - val_loss: 0.0483
# Epoch 84/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9259 - auc: 0.9716 - loss: 0.0483
# Epoch 84: val_auc improved from 0.97037 to 0.97048, saving model to ./model/best_bigru_model.keras
#
# Epoch 84: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - accuracy: 0.9268 - auc: 0.9708 - loss: 0.0486 - val_accuracy: 0.9269 - val_auc: 0.9705 - val_loss: 0.0484
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9231 - auc: 0.9709 - loss: 0.0487
# Epoch 85: val_auc did not improve from 0.97048
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.9255 - auc: 0.9704 - loss: 0.0488 - val_accuracy: 0.9269 - val_auc: 0.9704 - val_loss: 0.0483
# Epoch 86/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9252 - auc: 0.9705 - loss: 0.0488
# Epoch 86: val_auc improved from 0.97048 to 0.97053, saving model to ./model/best_bigru_model.keras
#
# Epoch 86: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - accuracy: 0.9262 - auc: 0.9698 - loss: 0.0490 - val_accuracy: 0.9264 - val_auc: 0.9705 - val_loss: 0.0482
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9245 - auc: 0.9705 - loss: 0.0488
# Epoch 87: val_auc improved from 0.97053 to 0.97086, saving model to ./model/best_bigru_model.keras
#
# Epoch 87: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - accuracy: 0.9252 - auc: 0.9701 - loss: 0.0489 - val_accuracy: 0.9264 - val_auc: 0.9709 - val_loss: 0.0480
# Epoch 88/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9252 - auc: 0.9720 - loss: 0.0480
# Epoch 88: val_auc improved from 0.97086 to 0.97098, saving model to ./model/best_bigru_model.keras
#
# Epoch 88: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 182ms/step - accuracy: 0.9254 - auc: 0.9713 - loss: 0.0483 - val_accuracy: 0.9269 - val_auc: 0.9710 - val_loss: 0.0480
# Epoch 89/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9263 - auc: 0.9721 - loss: 0.0477
# Epoch 89: val_auc improved from 0.97098 to 0.97101, saving model to ./model/best_bigru_model.keras
#
# Epoch 89: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - accuracy: 0.9277 - auc: 0.9716 - loss: 0.0478 - val_accuracy: 0.9269 - val_auc: 0.9710 - val_loss: 0.0480
# Epoch 90/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9254 - auc: 0.9715 - loss: 0.0480
# Epoch 90: val_auc improved from 0.97101 to 0.97118, saving model to ./model/best_bigru_model.keras
#
# Epoch 90: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - accuracy: 0.9252 - auc: 0.9709 - loss: 0.0483 - val_accuracy: 0.9275 - val_auc: 0.9712 - val_loss: 0.0478
# Epoch 91/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9267 - auc: 0.9716 - loss: 0.0481
# Epoch 91: val_auc improved from 0.97118 to 0.97127, saving model to ./model/best_bigru_model.keras
#
# Epoch 91: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - accuracy: 0.9264 - auc: 0.9708 - loss: 0.0484 - val_accuracy: 0.9269 - val_auc: 0.9713 - val_loss: 0.0479
# Epoch 92/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9255 - auc: 0.9722 - loss: 0.0478
# Epoch 92: val_auc improved from 0.97127 to 0.97144, saving model to ./model/best_bigru_model.keras
#
# Epoch 92: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 193ms/step - accuracy: 0.9266 - auc: 0.9714 - loss: 0.0481 - val_accuracy: 0.9275 - val_auc: 0.9714 - val_loss: 0.0479
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9240 - auc: 0.9719 - loss: 0.0481
# Epoch 93: val_auc did not improve from 0.97144
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 194ms/step - accuracy: 0.9252 - auc: 0.9709 - loss: 0.0485 - val_accuracy: 0.9264 - val_auc: 0.9714 - val_loss: 0.0479
# Epoch 94/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9230 - auc: 0.9726 - loss: 0.0478
# Epoch 94: val_auc did not improve from 0.97144
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 187ms/step - accuracy: 0.9251 - auc: 0.9718 - loss: 0.0479 - val_accuracy: 0.9264 - val_auc: 0.9714 - val_loss: 0.0477
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9264 - auc: 0.9725 - loss: 0.0474
# Epoch 95: val_auc improved from 0.97144 to 0.97168, saving model to ./model/best_bigru_model.keras
#
# Epoch 95: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 196ms/step - accuracy: 0.9262 - auc: 0.9718 - loss: 0.0477 - val_accuracy: 0.9286 - val_auc: 0.9717 - val_loss: 0.0476
# Epoch 96/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9268 - auc: 0.9731 - loss: 0.0471
# Epoch 96: val_auc improved from 0.97168 to 0.97173, saving model to ./model/best_bigru_model.keras
#
# Epoch 96: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - accuracy: 0.9271 - auc: 0.9724 - loss: 0.0474 - val_accuracy: 0.9275 - val_auc: 0.9717 - val_loss: 0.0475
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9257 - auc: 0.9720 - loss: 0.0481
# Epoch 97: val_auc improved from 0.97173 to 0.97193, saving model to ./model/best_bigru_model.keras
#
# Epoch 97: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - accuracy: 0.9268 - auc: 0.9719 - loss: 0.0479 - val_accuracy: 0.9280 - val_auc: 0.9719 - val_loss: 0.0476
# Epoch 98/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9265 - auc: 0.9734 - loss: 0.0471
# Epoch 98: val_auc improved from 0.97193 to 0.97209, saving model to ./model/best_bigru_model.keras
#
# Epoch 98: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - accuracy: 0.9262 - auc: 0.9725 - loss: 0.0475 - val_accuracy: 0.9286 - val_auc: 0.9721 - val_loss: 0.0473
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9254 - auc: 0.9733 - loss: 0.0469
# Epoch 99: val_auc improved from 0.97209 to 0.97227, saving model to ./model/best_bigru_model.keras
#
# Epoch 99: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - accuracy: 0.9262 - auc: 0.9724 - loss: 0.0474 - val_accuracy: 0.9291 - val_auc: 0.9723 - val_loss: 0.0473
# Epoch 100/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9229 - auc: 0.9727 - loss: 0.0475
# Epoch 100: val_auc did not improve from 0.97227
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9255 - auc: 0.9721 - loss: 0.0477 - val_accuracy: 0.9297 - val_auc: 0.9722 - val_loss: 0.0473
# Restoring model weights from the end of the best epoch: 99.
#
# Evaluating model...
#
# TRAINING COMPLETE
# ==================================================
# Model  Accuracy  Precision   Recall       F1  TP  TN  FP  FN Training_Time  Epochs
# BiGRU  0.933442    0.97669 0.891489 0.932147 838 873  20 102       0:10:20     100

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import os

# ==============================
# Directory setup
# ==============================

MODEL_NAME = "BiGRU+CONV"

CSV_PATH = "./csv"
IMAGE_PATH = "./image"

os.makedirs(CSV_PATH, exist_ok=True)
os.makedirs(IMAGE_PATH, exist_ok=True)

METRIC_FILE = os.path.join(CSV_PATH, f"{MODEL_NAME}_metrics.csv")
HISTORY_FILE = os.path.join(CSV_PATH, f"{MODEL_NAME}_training_history.csv")
PLOT_FILE = os.path.join(IMAGE_PATH, f"{MODEL_NAME}_history.png")


# ==============================
# Metrics Class
# ==============================

class ComputeMetrics:
    """Class to compute and manage classification metrics."""

    def __init__(self, y_true, y_pred):
        self.y_true = y_true.flatten() if y_true.ndim > 1 else y_true
        self.y_pred = y_pred.flatten() if y_pred.ndim > 1 else y_pred

    def get_confusion_matrix(self):
        return confusion_matrix(self.y_true, self.y_pred)

    def get_precision(self):
        return precision_score(self.y_true, self.y_pred, zero_division=0)

    def get_recall(self):
        return recall_score(self.y_true, self.y_pred, zero_division=0)

    def get_f1_score(self):
        return f1_score(self.y_true, self.y_pred, zero_division=0)

    def get_accuracy(self):
        return accuracy_score(self.y_true, self.y_pred)

    def get_all_metrics(self):
        cm = self.get_confusion_matrix()
        tn, fp, fn, tp = cm.ravel()

        return {
            "TP": int(tp),
            "TN": int(tn),
            "FP": int(fp),
            "FN": int(fn),
            "Precision": float(self.get_precision()),
            "Recall": float(self.get_recall()),
            "F1-Score": float(self.get_f1_score()),
            "Accuracy": float(self.get_accuracy())
        }


# ==============================
# Predict
# ==============================

y_pred = (model.predict(X_test) > 0.5).astype(int)

metrics_calculator = ComputeMetrics(y_test, y_pred)
metrics = metrics_calculator.get_all_metrics()

print("\n" + "="*50)
print("CLASSIFICATION METRICS ON TEST SET")
print("="*50)

for key, value in metrics.items():
    if isinstance(value, float):
        print(f"{key:12s}: {value:.4f}")
    else:
        print(f"{key:12s}: {value}")


# ==============================
# Save Metrics
# ==============================

metrics_df = pd.DataFrame([metrics])
metrics_df.insert(0, "Model", MODEL_NAME)
metrics_df.to_csv(METRIC_FILE, index=False)

print(f"\n✓ Metrics saved to: {METRIC_FILE}")


# ==============================
# Plot Training History
# ==============================

print("\n" + "="*50)
print("TRAINING HISTORY VISUALIZATION")
print("="*50)

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Accuracy
axes[0].plot(history.history["accuracy"], label="Train Accuracy", linewidth=2)
axes[0].plot(history.history["val_accuracy"], label="Val Accuracy", linewidth=2)

axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Accuracy")
axes[0].set_title("Model Accuracy per Epoch")
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Loss
axes[1].plot(history.history["loss"], label="Train Loss", linewidth=2)
axes[1].plot(history.history["val_loss"], label="Val Loss", linewidth=2)

axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss")
axes[1].set_title("Model Loss per Epoch")
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(PLOT_FILE, dpi=300, bbox_inches="tight")

print(f"✓ Training history plot saved to: {PLOT_FILE}")

plt.show()


# ==============================
# Save Training History CSV
# ==============================

history_df = pd.DataFrame({
    "epoch": range(1, len(history.history["accuracy"]) + 1),
    "train_accuracy": history.history["accuracy"],
    "val_accuracy": history.history["val_accuracy"],
    "train_loss": history.history["loss"],
    "val_loss": history.history["val_loss"]
})

history_df.to_csv(HISTORY_FILE, index=False)

print(f"✓ Training history saved to: {HISTORY_FILE}")
print("="*50)
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step
#
# ==================================================
# CLASSIFICATION METRICS ON TEST SET
# ==================================================
# TP          : 838
# TN          : 873
# FP          : 20
# FN          : 102
# Precision   : 0.9767
# Recall      : 0.8915
# F1-Score    : 0.9321
# Accuracy    : 0.9334
#
# ✓ Metrics saved to: ./csv/BiGRU+CONV_metrics.csv
#
# ==================================================
# TRAINING HISTORY VISUALIZATION
# ==================================================
# ✓ Training history plot saved to: ./image/BiGRU+CONV_history.png
# ✓ Training history saved to: ./csv/BiGRU+CONV_training_history.csv
# ==================================================

# %%
import seaborn as sns
import os
from matplotlib import pyplot as plt

MODEL_NAME = "BiGRU+CONV"

IMAGE_PATH = "./image"
os.makedirs(IMAGE_PATH, exist_ok=True)

CM_FILE = os.path.join(IMAGE_PATH, f"{MODEL_NAME}_confusion_matrix.png")


# ==============================
# Confusion Matrix Visualization
# ==============================

print("\n" + "="*50)
print("CONFUSION MATRIX VISUALIZATION")
print("="*50)

cm = metrics_calculator.get_confusion_matrix()

fig, ax = plt.subplots(figsize=(8,6))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Negative","Positive"],
    yticklabels=["Negative","Positive"],
    cbar_kws={"label":"Count"},
    annot_kws={"size":14},
    ax=ax
)

ax.set_xlabel("Predicted Label", fontsize=12, fontweight="bold")
ax.set_ylabel("True Label", fontsize=12, fontweight="bold")
ax.set_title(f"Confusion Matrix - {MODEL_NAME}", fontsize=14, fontweight="bold")

plt.tight_layout()
plt.savefig(CM_FILE, dpi=300, bbox_inches="tight")

print(f"✓ Confusion matrix saved to: {CM_FILE}")

plt.show()


# ==============================
# Metrics Summary Table
# ==============================

print("\n" + "="*50)
print("METRICS SUMMARY TABLE")
print("="*50)

print(metrics_df.to_string(index=False))

print("="*50)
# Out:
# ==================================================
# CONFUSION MATRIX VISUALIZATION
# ==================================================
# ✓ Confusion matrix saved to: ./image/BiGRU+CONV_confusion_matrix.png
# ==================================================
# METRICS SUMMARY TABLE
# ==================================================
#      Model  TP  TN  FP  FN  Precision   Recall  F1-Score  Accuracy
# BiGRU+CONV 838 873  20 102    0.97669 0.891489  0.932147  0.933442
# ==================================================
