# %%
# load the datapath that has been cleaned and preprocessed 

import pandas as pd

# Dataset paths
DATA_PATHS = {
    "train": "/home/gibannn/kuliah/sem3/paper/SMILES2VEC/code/SMILES/train_set_balanced.xlsx",
    "test":  "/home/gibannn/kuliah/sem3/paper/SMILES2VEC/code/SMILES/test_set_balanced.xlsx",
    "val":   "/home/gibannn/kuliah/sem3/paper/SMILES2VEC/code/SMILES/val_set_balanced.xlsx"
}

print("Datapaths loaded\n")


def load_dataset(path, name):
    """Load dataset and split into features (X) and labels (y)."""
    
    df = pd.read_excel(path)
    
    X = df.drop(columns="labels")
    y = df["labels"]

    print(f"{name.upper()} DATA")
    print(f"X_{name} shape: {X.shape} | y_{name} shape: {y.shape}")
    
    label_dist = y.value_counts().rename(index={0: "Label 0", 1: "Label 1"})
    print("Label distribution:\n", label_dist, "\n")

    return X, y


# Load datasets
X_train, y_train = load_dataset(DATA_PATHS["train"], "train")
X_test, y_test   = load_dataset(DATA_PATHS["test"], "test")
X_val, y_val     = load_dataset(DATA_PATHS["val"], "val")
# Out:
# Datapaths loaded
#
# TRAIN DATA
# X_train shape: (8260, 271) | y_train shape: (8260,)
# Label distribution:
#  labels
# Label 0    4167
# Label 1    4093
# Name: count, dtype: int64
#
# TEST DATA
# X_test shape: (1833, 271) | y_test shape: (1833,)
# Label distribution:
#  labels
# Label 1    940
# Label 0    893
# Name: count, dtype: int64
#
# VAL DATA
# X_val shape: (1806, 271) | y_val shape: (1806,)
# Label distribution:
#  labels
# Label 1    913
# Label 0    893
# Name: count, dtype: int64

# %%
vocab_size = int(
    max(
        X_train.to_numpy().max(),
        X_test.to_numpy().max(),
        X_val.to_numpy().max()
    )
)

# Maximum sequence length
MAX_LEN = X_train.shape[1]

print("Dataset Statistics")
print("------------------")
print(f"Vocabulary size: {vocab_size}")
print(f"Max sequence length: {MAX_LEN}")

print("\nClass distribution in training set (after ADASYN balancing):")
print(
    y_train.value_counts()
    .rename(index={
        0: "Label 0 (Negative)",
        1: "Label 1 (Positive)"
    })
)
# Out:
# Dataset Statistics
# ------------------
# Vocabulary size: 132
# Max sequence length: 271
#
# Class distribution in training set (after ADASYN balancing):
# labels
# Label 0 (Negative)    4167
# Label 1 (Positive)    4093
# Name: count, dtype: int64

# %%
# ================================
# Environment Configuration
# ================================
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"       # Suppress TensorFlow logs
os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"     # Use GPU 0 and 1
os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"      # Disable OneDNN optimizations


# ================================
# Imports
# ================================
import warnings
import random
import time

import numpy as np
import tensorflow as tf
import sklearn.metrics as metrics

warnings.filterwarnings("ignore", category=FutureWarning)


# ================================
# Reproducibility
# ================================
RANDOM_STATE = 116

def set_seeds(seed: int = 116):
    """Set seeds for reproducibility."""
    np.random.seed(seed)
    random.seed(seed)
    tf.random.set_seed(seed)


set_seeds(RANDOM_STATE)


# ================================
# GPU Configuration
# ================================
def setup_gpu():
    """Configure TensorFlow GPU memory growth."""
    
    gpus = tf.config.list_physical_devices("GPU")

    if not gpus:
        print("No GPU detected. Using CPU.")
        return

    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)

        logical_gpus = tf.config.list_logical_devices("GPU")

        print(f"GPUs available: {len(gpus)} physical | {len(logical_gpus)} logical")

    except RuntimeError as e:
        print("GPU setup failed:", e)


setup_gpu()


# ================================
# Training Configuration
# ================================
def set_training_config(batch_size=256, iterations=128, epochs=100):
    """Define training hyperparameters."""
    
    config = {
        "BATCH_SIZE": batch_size,
        "ITERATIONS": iterations,
        "EPOCHS": epochs
    }

    return config


TRAIN_CONFIG = set_training_config()

BATCH_SIZE = TRAIN_CONFIG["BATCH_SIZE"]
ITERATIONS = TRAIN_CONFIG["ITERATIONS"]
EPOCHS = TRAIN_CONFIG["EPOCHS"]

print(f"Training config -> Batch: {BATCH_SIZE} | Iterations: {ITERATIONS} | Epochs: {EPOCHS}")
# Out:
# /home/gibannn/miniconda3/envs/RISET-SMILES/lib/python3.11/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# GPUs available: 1 physical | 1 logical
# Training config -> Batch: 256 | Iterations: 128 | Epochs: 100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773713220.106020   71249 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5560 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:65:00.0, compute capability: 8.9

# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Embedding, Conv1D, BatchNormalization,
    MaxPooling1D, GRU, Bidirectional,
    Dense, Dropout
)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import plot_model



# Paths (simple and portable)

MODEL_DIR = "./model"
IMAGE_DIR = "./image"

os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(IMAGE_DIR, exist_ok=True)

MODEL_FILE = os.path.join(MODEL_DIR, "best_bigru_conv_model.h5")
MODEL_IMAGE = os.path.join(IMAGE_DIR, "bigru_conv_architecture.png")



# Model Architecture

def build_bigru_conv_model(sequence_length, vocabulary_size):

    set_seeds(RANDOM_STATE)

    model = Sequential([

        # Embedding
        Embedding(
            input_dim=vocabulary_size + 1,
            output_dim=128,
            mask_zero=False
        ),
         
        #add convolutional block
        Conv1D(64, kernel_size=5, activation="relu", padding="same"),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),

        # add third layer of bidirectional GRU
        Bidirectional(
            GRU(
                128,
                return_sequences=True,
                dropout=0.3
            )
        ),

        #add second layer of Bidirectional GRU
        Bidirectional(
            GRU(
                64,
                return_sequences=True,
                dropout=0.3
            )
        ),

        # Bidirectional GRU
        Bidirectional(
            GRU(
                32,
                return_sequences=False,
                dropout=0.3
            )
        ),

        # Dense head
        Dense(64, activation="relu"),
        Dropout(0.4),   

        #adding flatten layer
        tf.keras.layers.Flatten(),

        # Output layer
        Dense(1, activation="sigmoid")
    ])

    return model



# Build Model

model = build_bigru_conv_model(MAX_LEN, vocab_size)

loss = tf.keras.losses.BinaryFocalCrossentropy(gamma=2)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss=loss,
    metrics=[
        "accuracy",
        tf.keras.metrics.AUC(name="auc")
    ]
)

model.build(input_shape=(None, MAX_LEN))

print("Model built successfully")
model.summary()



# Callbacks

early_stopping = EarlyStopping(
    monitor="val_auc",
    mode="max",
    patience=3,
    restore_best_weights=True,
    verbose=1
)

model_checkpoint = ModelCheckpoint(
    filepath=MODEL_FILE,
    monitor="val_auc",
    mode="max",
    save_best_only=True,
    verbose=1
)


# Save Model Architecture Diagram
plot_model(
    model,
    to_file=MODEL_IMAGE,
    show_shapes=True,
    show_layer_names=True
)

print(f"Model diagram saved to: {MODEL_IMAGE}")
# Out:
# /home/gibannn/miniconda3/envs/RISET-SMILES/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model built successfully
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 271, 128)       │        17,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 271, 64)        │        41,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 271, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 135, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 135, 256)       │       148,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 135, 128)       │       123,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 64)             │        31,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 366,273 (1.40 MB)
#  Trainable params: 366,145 (1.40 MB)
#  Non-trainable params: 128 (512.00 B)
# Model diagram saved to: ./image/bigru_conv_architecture.png

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score

def compute_classification_metrics(y_true, y_pred):
    """
    Returns TP, TN, FP, FN, Precision, Recall, F1, Accuracy
    """
    cm = confusion_matrix(y_true, y_pred)
    
    tn, fp, fn, tp = cm.ravel()

    precision = precision_score(y_true, y_pred, zero_division=0)
    recall    = recall_score(y_true, y_pred, zero_division=0)
    f1        = f1_score(y_true, y_pred, zero_division=0)
    accuracy  = accuracy_score(y_true, y_pred)

    return {
        "TP": tp,
        "TN": tn,
        "FP": fp,
        "FN": fn,
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1,
        "Accuracy": accuracy
    }

print("the function to compute classification metrics have been defined")
# Out:
# the function to compute classification metrics have been defined

# %%
import os
import time
import pandas as pd
import numpy as np
import tensorflow as tf
from datetime import timedelta
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


def to_numpy(x):
    """Convert pandas objects to numpy arrays."""
    return x.values if hasattr(x, "values") else x


def train_and_evaluate_model(
    X_train, y_train,
    X_val, y_val,
    X_test, y_test,
    epochs=100,
    batch_size=128,
    learning_rate=3e-4,
    model_name="BiGRU+CNN",
    model_save_path="./model/best_model.keras",
    patience=5,
    verbose=1
):
    """
    Train and evaluate sequence classification model.
    """

    print(f"TRAINING {model_name}")
    print("=" * 50)

    start_time = time.time()

    # Convert datasets
    X_train, y_train = to_numpy(X_train), to_numpy(y_train)
    X_val, y_val = to_numpy(X_val), to_numpy(y_val)
    X_test, y_test = to_numpy(X_test), to_numpy(y_test)

    
    # Build model
    
    print("\nBuilding model...")
    model = build_bigru_conv_model(MAX_LEN, vocab_size)

    
    # Compile
    
    print("[2/4] Compiling model...")

    loss_fn = tf.keras.losses.BinaryFocalCrossentropy(gamma=2)

    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss=loss_fn,
        metrics=[
            "accuracy",
            tf.keras.metrics.AUC(name="auc")
        ]
    )

    model.build(input_shape=(None, MAX_LEN))

    if verbose:
        model.summary()

    
    # Callbacks
    
    os.makedirs(os.path.dirname(model_save_path), exist_ok=True)

    callbacks = [

        EarlyStopping(
            monitor="val_auc",
            mode="max",
            patience=patience,
            restore_best_weights=True,
            verbose=1
        ),

        ModelCheckpoint(
            filepath=model_save_path,
            monitor="val_auc",
            mode="max",
            save_best_only=True,
            verbose=1
        )
    ]

    
    # Training
    
    print("\nTraining model...")
    print(f"Epochs: {epochs}")
    print(f"Batch size: {batch_size}")
    print(f"Training samples: {len(X_train)}")

    history = model.fit(
        X_train,
        y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=callbacks,
        verbose=verbose
    )

    training_time = time.time() - start_time

    
    # Evaluation
    
    print("\nEvaluating model...")

    y_pred_prob = model.predict(X_test, verbose=0)
    y_pred = (y_pred_prob > 0.5).astype(int)

    metrics_dict = compute_classification_metrics(y_test, y_pred)

    results_df = pd.DataFrame([{
        "Model": model_name,
        "Accuracy": metrics_dict["Accuracy"],
        "Precision": metrics_dict["Precision"],
        "Recall": metrics_dict["Recall"],
        "F1": metrics_dict["F1-Score"],
        "TP": metrics_dict["TP"],
        "TN": metrics_dict["TN"],
        "FP": metrics_dict["FP"],
        "FN": metrics_dict["FN"],
        "Training_Time": str(timedelta(seconds=int(training_time))),
        "Epochs": len(history.history["loss"])
    }])

    print("\nTRAINING COMPLETE")
    print("=" * 50)
    print(results_df.to_string(index=False))

    return model, history, results_df

# %%
model, history, results = train_and_evaluate_model(
    X_train,
    y_train,
    X_val,
    y_val,
    X_test,
    y_test,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    model_name="BiGRU",
    model_save_path="./model/best_bigru_model.keras"
)
# Out:
# TRAINING BiGRU
# ==================================================
#
# Building model...
# [2/4] Compiling model...
# /home/gibannn/miniconda3/envs/RISET-SMILES/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 271, 128)       │        17,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 271, 64)        │        41,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 271, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 135, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ (None, 135, 256)       │       148,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_4 (Bidirectional) │ (None, 135, 128)       │       123,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_5 (Bidirectional) │ (None, 64)             │        31,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 366,273 (1.40 MB)
#  Trainable params: 366,145 (1.40 MB)
#  Non-trainable params: 128 (512.00 B)
# Training model...
# Epochs: 100
# Batch size: 256
# Training samples: 8260
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6451 - auc: 0.6980 - loss: 0.1556
# Epoch 1: val_auc improved from None to 0.93358, saving model to ./model/best_bigru_model.keras
#
# Epoch 1: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 27s 336ms/step - accuracy: 0.7414 - auc: 0.8201 - loss: 0.1313 - val_accuracy: 0.8261 - val_auc: 0.9336 - val_loss: 0.1566
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.8704 - auc: 0.9220 - loss: 0.0859
# Epoch 2: val_auc improved from 0.93358 to 0.96080, saving model to ./model/best_bigru_model.keras
#
# Epoch 2: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 289ms/step - accuracy: 0.8810 - auc: 0.9292 - loss: 0.0804 - val_accuracy: 0.7475 - val_auc: 0.9608 - val_loss: 0.1431
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9010 - auc: 0.9424 - loss: 0.0694
# Epoch 3: val_auc improved from 0.96080 to 0.96682, saving model to ./model/best_bigru_model.keras
#
# Epoch 3: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 287ms/step - accuracy: 0.9041 - auc: 0.9478 - loss: 0.0665 - val_accuracy: 0.7508 - val_auc: 0.9668 - val_loss: 0.1337
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.9108 - auc: 0.9548 - loss: 0.0612
# Epoch 4: val_auc improved from 0.96682 to 0.96916, saving model to ./model/best_bigru_model.keras
#
# Epoch 4: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 273ms/step - accuracy: 0.9120 - auc: 0.9564 - loss: 0.0605 - val_accuracy: 0.7829 - val_auc: 0.9692 - val_loss: 0.1189
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9150 - auc: 0.9588 - loss: 0.0588
# Epoch 5: val_auc improved from 0.96916 to 0.97121, saving model to ./model/best_bigru_model.keras
#
# Epoch 5: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 296ms/step - accuracy: 0.9159 - auc: 0.9601 - loss: 0.0577 - val_accuracy: 0.8555 - val_auc: 0.9712 - val_loss: 0.0997
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9213 - auc: 0.9665 - loss: 0.0529
# Epoch 6: val_auc improved from 0.97121 to 0.97217, saving model to ./model/best_bigru_model.keras
#
# Epoch 6: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 293ms/step - accuracy: 0.9209 - auc: 0.9663 - loss: 0.0531 - val_accuracy: 0.8649 - val_auc: 0.9722 - val_loss: 0.0886
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9214 - auc: 0.9666 - loss: 0.0526
# Epoch 7: val_auc improved from 0.97217 to 0.97395, saving model to ./model/best_bigru_model.keras
#
# Epoch 7: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 298ms/step - accuracy: 0.9225 - auc: 0.9674 - loss: 0.0520 - val_accuracy: 0.8743 - val_auc: 0.9740 - val_loss: 0.0816
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9207 - auc: 0.9682 - loss: 0.0522
# Epoch 8: val_auc improved from 0.97395 to 0.97462, saving model to ./model/best_bigru_model.keras
#
# Epoch 8: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 302ms/step - accuracy: 0.9241 - auc: 0.9696 - loss: 0.0503 - val_accuracy: 0.8904 - val_auc: 0.9746 - val_loss: 0.0738
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9286 - auc: 0.9721 - loss: 0.0483
# Epoch 9: val_auc improved from 0.97462 to 0.97575, saving model to ./model/best_bigru_model.keras
#
# Epoch 9: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 280ms/step - accuracy: 0.9283 - auc: 0.9731 - loss: 0.0472 - val_accuracy: 0.9086 - val_auc: 0.9757 - val_loss: 0.0641
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9269 - auc: 0.9736 - loss: 0.0474
# Epoch 10: val_auc improved from 0.97575 to 0.97635, saving model to ./model/best_bigru_model.keras
#
# Epoch 10: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 284ms/step - accuracy: 0.9280 - auc: 0.9737 - loss: 0.0467 - val_accuracy: 0.9153 - val_auc: 0.9763 - val_loss: 0.0578
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9287 - auc: 0.9760 - loss: 0.0457
# Epoch 11: val_auc did not improve from 0.97635
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 285ms/step - accuracy: 0.9306 - auc: 0.9760 - loss: 0.0452 - val_accuracy: 0.9230 - val_auc: 0.9759 - val_loss: 0.0518
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9323 - auc: 0.9758 - loss: 0.0460
# Epoch 12: val_auc improved from 0.97635 to 0.97780, saving model to ./model/best_bigru_model.keras
#
# Epoch 12: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 275ms/step - accuracy: 0.9345 - auc: 0.9770 - loss: 0.0440 - val_accuracy: 0.9208 - val_auc: 0.9778 - val_loss: 0.0528
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9348 - auc: 0.9782 - loss: 0.0445
# Epoch 13: val_auc improved from 0.97780 to 0.97848, saving model to ./model/best_bigru_model.keras
#
# Epoch 13: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 294ms/step - accuracy: 0.9350 - auc: 0.9782 - loss: 0.0436 - val_accuracy: 0.9241 - val_auc: 0.9785 - val_loss: 0.0490
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9338 - auc: 0.9814 - loss: 0.0409
# Epoch 14: val_auc did not improve from 0.97848
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 276ms/step - accuracy: 0.9357 - auc: 0.9806 - loss: 0.0410 - val_accuracy: 0.9252 - val_auc: 0.9781 - val_loss: 0.0519
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9357 - auc: 0.9823 - loss: 0.0403
# Epoch 15: val_auc improved from 0.97848 to 0.97854, saving model to ./model/best_bigru_model.keras
#
# Epoch 15: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 283ms/step - accuracy: 0.9374 - auc: 0.9816 - loss: 0.0402 - val_accuracy: 0.9319 - val_auc: 0.9785 - val_loss: 0.0442
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9400 - auc: 0.9820 - loss: 0.0399
# Epoch 16: val_auc improved from 0.97854 to 0.97915, saving model to ./model/best_bigru_model.keras
#
# Epoch 16: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 271ms/step - accuracy: 0.9407 - auc: 0.9817 - loss: 0.0401 - val_accuracy: 0.9302 - val_auc: 0.9792 - val_loss: 0.0490
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9363 - auc: 0.9835 - loss: 0.0389
# Epoch 17: val_auc improved from 0.97915 to 0.97977, saving model to ./model/best_bigru_model.keras
#
# Epoch 17: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 275ms/step - accuracy: 0.9395 - auc: 0.9832 - loss: 0.0390 - val_accuracy: 0.9363 - val_auc: 0.9798 - val_loss: 0.0422
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9364 - auc: 0.9841 - loss: 0.0385
# Epoch 18: val_auc improved from 0.97977 to 0.98042, saving model to ./model/best_bigru_model.keras
#
# Epoch 18: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 294ms/step - accuracy: 0.9393 - auc: 0.9843 - loss: 0.0379 - val_accuracy: 0.9341 - val_auc: 0.9804 - val_loss: 0.0496
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9366 - auc: 0.9830 - loss: 0.0394
# Epoch 19: val_auc improved from 0.98042 to 0.98067, saving model to ./model/best_bigru_model.keras
#
# Epoch 19: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 294ms/step - accuracy: 0.9408 - auc: 0.9837 - loss: 0.0383 - val_accuracy: 0.9408 - val_auc: 0.9807 - val_loss: 0.0411
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9390 - auc: 0.9855 - loss: 0.0370
# Epoch 20: val_auc did not improve from 0.98067
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 270ms/step - accuracy: 0.9431 - auc: 0.9858 - loss: 0.0362 - val_accuracy: 0.9374 - val_auc: 0.9798 - val_loss: 0.0489
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9371 - auc: 0.9844 - loss: 0.0386
# Epoch 21: val_auc improved from 0.98067 to 0.98135, saving model to ./model/best_bigru_model.keras
#
# Epoch 21: finished saving model to ./model/best_bigru_model.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 281ms/step - accuracy: 0.9383 - auc: 0.9842 - loss: 0.0384 - val_accuracy: 0.9396 - val_auc: 0.9813 - val_loss: 0.0449
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9440 - auc: 0.9872 - loss: 0.0350
# Epoch 22: val_auc did not improve from 0.98135
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 271ms/step - accuracy: 0.9453 - auc: 0.9870 - loss: 0.0349 - val_accuracy: 0.9396 - val_auc: 0.9813 - val_loss: 0.0481
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9431 - auc: 0.9862 - loss: 0.0364
# Epoch 23: val_auc did not improve from 0.98135
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 269ms/step - accuracy: 0.9449 - auc: 0.9862 - loss: 0.0357 - val_accuracy: 0.9435 - val_auc: 0.9805 - val_loss: 0.0436
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9447 - auc: 0.9881 - loss: 0.0339
# Epoch 24: val_auc did not improve from 0.98135
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 270ms/step - accuracy: 0.9449 - auc: 0.9878 - loss: 0.0339 - val_accuracy: 0.9424 - val_auc: 0.9812 - val_loss: 0.0440
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9402 - auc: 0.9861 - loss: 0.0376
# Epoch 25: val_auc did not improve from 0.98135
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 280ms/step - accuracy: 0.9436 - auc: 0.9859 - loss: 0.0367 - val_accuracy: 0.9413 - val_auc: 0.9806 - val_loss: 0.0452
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9466 - auc: 0.9883 - loss: 0.0347
# Epoch 26: val_auc did not improve from 0.98135
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 274ms/step - accuracy: 0.9469 - auc: 0.9881 - loss: 0.0340 - val_accuracy: 0.9435 - val_auc: 0.9810 - val_loss: 0.0498
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 21.
#
# Evaluating model...
#
# TRAINING COMPLETE
# ==================================================
# Model  Accuracy  Precision   Recall       F1  TP  TN  FP  FN Training_Time  Epochs
# BiGRU  0.942171   0.992908 0.893617 0.940649 840 887   6 100       0:04:21      26

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import os

# ==============================
# Directory setup
# ==============================

MODEL_NAME = "BiGRU+CONV"

CSV_PATH = "./csv"
IMAGE_PATH = "./image"

os.makedirs(CSV_PATH, exist_ok=True)
os.makedirs(IMAGE_PATH, exist_ok=True)

METRIC_FILE = os.path.join(CSV_PATH, f"{MODEL_NAME}_metrics.csv")
HISTORY_FILE = os.path.join(CSV_PATH, f"{MODEL_NAME}_training_history.csv")
PLOT_FILE = os.path.join(IMAGE_PATH, f"{MODEL_NAME}_history.png")


# ==============================
# Metrics Class
# ==============================

class ComputeMetrics:
    """Class to compute and manage classification metrics."""

    def __init__(self, y_true, y_pred):
        self.y_true = y_true.flatten() if y_true.ndim > 1 else y_true
        self.y_pred = y_pred.flatten() if y_pred.ndim > 1 else y_pred

    def get_confusion_matrix(self):
        return confusion_matrix(self.y_true, self.y_pred)

    def get_precision(self):
        return precision_score(self.y_true, self.y_pred, zero_division=0)

    def get_recall(self):
        return recall_score(self.y_true, self.y_pred, zero_division=0)

    def get_f1_score(self):
        return f1_score(self.y_true, self.y_pred, zero_division=0)

    def get_accuracy(self):
        return accuracy_score(self.y_true, self.y_pred)

    def get_all_metrics(self):
        cm = self.get_confusion_matrix()
        tn, fp, fn, tp = cm.ravel()

        return {
            "TP": int(tp),
            "TN": int(tn),
            "FP": int(fp),
            "FN": int(fn),
            "Precision": float(self.get_precision()),
            "Recall": float(self.get_recall()),
            "F1-Score": float(self.get_f1_score()),
            "Accuracy": float(self.get_accuracy())
        }


# ==============================
# Predict
# ==============================

y_pred = (model.predict(X_test) > 0.5).astype(int)

metrics_calculator = ComputeMetrics(y_test, y_pred)
metrics = metrics_calculator.get_all_metrics()

print("\n" + "="*50)
print("CLASSIFICATION METRICS ON TEST SET")
print("="*50)

for key, value in metrics.items():
    if isinstance(value, float):
        print(f"{key:12s}: {value:.4f}")
    else:
        print(f"{key:12s}: {value}")


# ==============================
# Save Metrics
# ==============================

metrics_df = pd.DataFrame([metrics])
metrics_df.insert(0, "Model", MODEL_NAME)
metrics_df.to_csv(METRIC_FILE, index=False)

print(f"\n✓ Metrics saved to: {METRIC_FILE}")


# ==============================
# Plot Training History
# ==============================

print("\n" + "="*50)
print("TRAINING HISTORY VISUALIZATION")
print("="*50)

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Accuracy
axes[0].plot(history.history["accuracy"], label="Train Accuracy", linewidth=2)
axes[0].plot(history.history["val_accuracy"], label="Val Accuracy", linewidth=2)

axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Accuracy")
axes[0].set_title("Model Accuracy per Epoch")
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Loss
axes[1].plot(history.history["loss"], label="Train Loss", linewidth=2)
axes[1].plot(history.history["val_loss"], label="Val Loss", linewidth=2)

axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss")
axes[1].set_title("Model Loss per Epoch")
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(PLOT_FILE, dpi=300, bbox_inches="tight")

print(f"✓ Training history plot saved to: {PLOT_FILE}")

plt.show()


# ==============================
# Save Training History CSV
# ==============================

history_df = pd.DataFrame({
    "epoch": range(1, len(history.history["accuracy"]) + 1),
    "train_accuracy": history.history["accuracy"],
    "val_accuracy": history.history["val_accuracy"],
    "train_loss": history.history["loss"],
    "val_loss": history.history["val_loss"]
})

history_df.to_csv(HISTORY_FILE, index=False)

print(f"✓ Training history saved to: {HISTORY_FILE}")
print("="*50)
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step
#
# ==================================================
# CLASSIFICATION METRICS ON TEST SET
# ==================================================
# TP          : 840
# TN          : 887
# FP          : 6
# FN          : 100
# Precision   : 0.9929
# Recall      : 0.8936
# F1-Score    : 0.9406
# Accuracy    : 0.9422
#
# ✓ Metrics saved to: ./csv/BiGRU+CONV_metrics.csv
#
# ==================================================
# TRAINING HISTORY VISUALIZATION
# ==================================================
# ✓ Training history plot saved to: ./image/BiGRU+CONV_history.png
# ✓ Training history saved to: ./csv/BiGRU+CONV_training_history.csv
# ==================================================

# %%
import seaborn as sns
import os
from matplotlib import pyplot as plt

MODEL_NAME = "BiGRU+CONV"

IMAGE_PATH = "./image"
os.makedirs(IMAGE_PATH, exist_ok=True)

CM_FILE = os.path.join(IMAGE_PATH, f"{MODEL_NAME}_confusion_matrix.png")


# ==============================
# Confusion Matrix Visualization
# ==============================

print("\n" + "="*50)
print("CONFUSION MATRIX VISUALIZATION")
print("="*50)

cm = metrics_calculator.get_confusion_matrix()

fig, ax = plt.subplots(figsize=(8,6))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Negative","Positive"],
    yticklabels=["Negative","Positive"],
    cbar_kws={"label":"Count"},
    annot_kws={"size":14},
    ax=ax
)

ax.set_xlabel("Predicted Label", fontsize=12, fontweight="bold")
ax.set_ylabel("True Label", fontsize=12, fontweight="bold")
ax.set_title(f"Confusion Matrix - {MODEL_NAME}", fontsize=14, fontweight="bold")

plt.tight_layout()
plt.savefig(CM_FILE, dpi=300, bbox_inches="tight")

print(f"✓ Confusion matrix saved to: {CM_FILE}")

plt.show()


# ==============================
# Metrics Summary Table
# ==============================

print("\n" + "="*50)
print("METRICS SUMMARY TABLE")
print("="*50)

print(metrics_df.to_string(index=False))

print("="*50)
# Out:
# ==================================================
# CONFUSION MATRIX VISUALIZATION
# ==================================================
# ✓ Confusion matrix saved to: ./image/BiGRU+CONV_confusion_matrix.png
# ==================================================
# METRICS SUMMARY TABLE
# ==================================================
#      Model  TP  TN  FP  FN  Precision   Recall  F1-Score  Accuracy
# BiGRU+CONV 840 887   6 100   0.992908 0.893617  0.940649  0.942171
# ==================================================
